# %% [markdown]
# # Odkrivanje enačb, 2. del: uporaba predznanja
#
# ## 1. Verjetnostne gramatike in knjižnica ProGED
# 1.1 Za odkrivanje enačb z verjetnostnimi gramatikami bomo uporabili knjižnico ProGED: https://github.com/brencej/ProGED.
# Instaliramo jo z ukazom "pip install git+https://github.com/brencej/ProGED". Če se pojavijo težave, ustvari sveže Pythonovo okolje in poskusi instalirati tja.
#
# Poglej si enostaven primer uporabe spodaj. Lahko se poigraš z različnimi nastavitvami in možnostmi. Celoten nabor modelov si lahko ogledaš v "ED.models".

# %%
import numpy as np
import pandas as pd

import ProGED as pg

from vajeED_2_podatki import *

# %%
podatki = generiraj_newton(100)

np.random.seed(1)
ED = pg.EqDisco(data=podatki, 
                lhs_vars=["F"],
                rhs_vars=["m", "a"],
                sample_size=10)

ED.generate_models()
ED.fit_models()
ED.get_results()
# Out:
# ModelBox: 1 models
# -> [0.999999997446936*a*m], p = 0.00023040000000000002, parse trees = 1, valid = True, error = 9.851219776892273e-10, time = 0.2802133560180664

# %% [markdown]
# 1.2 Prostor možnih enačb, ki ga želimo preiskovati, definiramo z verjetnostno kontekstno-neodvisno gramatiko. ProGED-u jo podamo v obliki stringa, zapisanega po pravilih knjižnice NLTK:
#
# - produkcijska pravila so oblike "A -> B1 ... Bn [p]", kjer je A neterminal, B1 ... Bn so terminali ali neterminali, p pa je verjetnost pravila
# - verjetnosti pravil z istim neterminalom na levi strani se morajo sešteti v 1
# - krajši zapis pravil z istim neterminalom na levi strani je "A -> B1 ... Bn [p] | D1 ... Dn [q] | ... "
# - terminalni simboli se označijo z enojnimi narekovaji, npr. "A -> B 'x'"
# - v ProGED-u je terminalni simbol "C" poseben - označuje numerične konstante, katerih vrednosti iščemo z optimizacijo
#
# Gramatika za linearne izraze dveh spremenljivk je
#
# E -> E + V | V
# V -> 'x' | 'y'
#
# Uporabi to gramatiko za odkrivanje enačbe $y = x_1 + 3x_2$. Podatke lahko generiraš z "generiraj_linearno". Koraki:
# 1. zapiši linearno gramatiko v formalizmu NLTK (ne pozabi da so tudi aritmetični operatorji terminalni simboli)
# 2. naredi ProGED-ov objekt GeneratorGrammar, ki kot argument sprejme string iz točke 1
# 3. gramatiko iz točke 2 podaj ProGED-ovemu EqDisco kot argument generator
# 4. generiraj 15 naključnih izrazov z ED.generate_models in si jih oglej
# 5. kliči še fit\_models in get\_results ter si oglej rezultate

# %%
podatki = generiraj_linearno(100)

grammar = "E -> E '+' V [0.6] | V [0.4]\n"
grammar += "V -> 'x1' [0.33] | 'x2' [0.67]"

grammar = pg.GeneratorGrammar(grammar)
ED = pg.EqDisco(data=podatki, 
                lhs_vars=["y"],
                rhs_vars=["x1", "x2"],
                sample_size=15,
                generator=grammar)

ED.generate_models()
# Out:
# ModelBox: 7 models
# -> [x1], p = 0.264, parse trees = 4, valid = False
# -> [2*x1 + 4*x2], p = 0.0006825639291989762, parse trees = 4, valid = False
# -> [x2], p = 0.536, parse trees = 4, valid = False
# -> [2*x1], p = 0.026136000000000003, parse trees = 4, valid = False
# -> [x1 + 3*x2], p = 0.017150709312000002, parse trees = 4, valid = False
# -> [x1 + 2*x2], p = 0.021331727999999998, parse trees = 4, valid = False
# -> [x1 + 4*x2], p = 0.0034472925717120005, parse trees = 4, valid = False

# %%
ED.fit_models()
ED.get_results()
# Out:
# ModelBox: 1 models
# -> [x1 + 3*x2], p = 0.017150709312000002, parse trees = 4, valid = True, error = 0.0, time = 0

# %% [markdown]
# Zdaj linearni gramatiki dodaj še numerično konstanto. Kako se spremenijo generirani modeli in rezultati?

# %%
podatki = generiraj_linearno(100)

grammar = "E -> E '+' 'C' '*' V [0.6] | 'C' '*' V [0.4]\n"
grammar += "V -> 'x1' [0.33] | 'x2' [0.67]"

grammar = pg.GeneratorGrammar(grammar)
ED = pg.EqDisco(data=podatki, 
                lhs_vars=["y"],
                rhs_vars=["x1", "x2"],
                sample_size=15,
                generator=grammar)

ED.generate_models()
# Out:
# ModelBox: 3 models
# -> [C0*x1], p = 0.158136, parse trees = 8, valid = False
# -> [C0*x1 + C1*x2], p = 0.0264769407936, parse trees = 8, valid = False
# -> [C0*x2], p = 0.31130987200000004, parse trees = 8, valid = False

# %%
ED.fit_models()
ED.get_results()
# Out:
# ModelBox: 1 models
# -> [0.999999993198693*x1 + 2.9999999995703*x2], p = 0.0264769407936, parse trees = 8, valid = True, error = 4.246193607440554e-09, time = 1.5937693119049072

# %% [markdown]
# 1.3. Napiši gramatiko, ki generira polinome, in jo uporabi za odkrivanje energijskega zakona. Verjetno bo potrebno zgenerirati nekaj sto modelov. Če bo imel ProGED težave z generiranjem toliko unikatnih izrazov, mu lahko daš več poskusov za generiranje z nastavitvijo "strategy_settings = {"max_repeat":1000}."
#
# Na prejšnjih vajah smo videli, da je šum velik trn v peti odkrivanja enačb. Kako vpliva šum na odkrivanje enačb z verjetnostnimi gramatikami?

# %%
podatki = generiraj_energijski_zakon(500, sum=0.1)

grammar = "P -> P '+' M [0.3] | M [0.7]\n"
grammar += "M -> M '*' F [0.5] | 'C' '*' F [0.5]\n"
grammar += "F -> 'm' [0.4] | 'h' [0.3] | 'v' [0.3]"

np.random.seed(1)
grammar = pg.GeneratorGrammar(grammar)
ED = pg.EqDisco(data=podatki, 
                sample_size=500,
                lhs_vars=["E"],
                rhs_vars=["m", "h", "v"],
                strategy_settings = {"max_repeat":1000},
                generator = grammar)

# %%
ED.generate_models()
# Out:
# ModelBox: 500 models
# -> [C0*m], p = 0.13999999999999999, parse trees = 414, valid = False
# -> [C0*h**2 + C1*h*m + C2*m**2 + C3*v], p = 7.6545e-08, parse trees = 414, valid = False
# -> [C0*h**2*m + C1*h*m + C2*v**2 + C3*v], p = 8.611312499999997e-09, parse trees = 414, valid = False
# -> [C0*h**3*m**2 + C1*h], p = 4.2524999999999995e-06, parse trees = 414, valid = False
# -> [C0*v], p = 0.105, parse trees = 414, valid = False
# -> [C0*m**2*v], p = 0.004200000000000001, parse trees = 414, valid = False
# -> [C0*h**2], p = 0.0001063125, parse trees = 414, valid = False
# -> [C0*m + C1*v], p = 0.00028349999999999995, parse trees = 414, valid = False
# -> [C0*h*v + C1*h + C2*m*v + C3*m], p = 3.8272499999999995e-07, parse trees = 414, valid = False
# -> [C0*h*m*v + C1*h*m + C2*m**2*v + C3*m + C4*v], p = 7.440173999999997e-14, parse trees = 414, valid = False
# -> [C0*h**2*m], p = 0.0031499999999999996, parse trees = 414, valid = False
# -> [C0*m + C1*v**2 + C2*v], p = 4.2525e-05, parse trees = 414, valid = False
# -> [C0*h*v], p = 0.01575, parse trees = 414, valid = False
# -> [C0*h*m*v**2 + C1*m*v + C2*v], p = 1.9136249999999992e-07, parse trees = 414, valid = False
# -> [C0*h + C1*m], p = 0.006299999999999999, parse trees = 414, valid = False
# -> [C0*h*v + C1*h], p = 0.00070875, parse trees = 414, valid = False
# -> [C0*h**3*m**2*v], p = 1.4175000000000002e-05, parse trees = 414, valid = False
# -> [C0*h], p = 0.105, parse trees = 414, valid = False
# -> [C0*h**2*m*v**2], p = 7.087499999999999e-05, parse trees = 414, valid = False
# -> [C0*m*v**2], p = 0.0031499999999999996, parse trees = 414, valid = False
# -> [C0*h**2*m + C1*h**2 + C2*m], p = 1.2757499999999996e-06, parse trees = 414, valid = False
# -> [C0*m*v], p = 0.020999999999999998, parse trees = 414, valid = False
# -> [C0*h*v + C1*m], p = 0.0009450000000000001, parse trees = 414, valid = False
# -> [C0*h + C1*m**2*v], p = 0.000189, parse trees = 414, valid = False
# -> [C0*h + C1*m**2*v + C2*m*v], p = 1.7009999999999995e-06, parse trees = 414, valid = False
# -> [C0*h*m*v**2 + C1*m**2], p = 5.670000000000001e-06, parse trees = 414, valid = False
# -> [C0*h*m*v**2 + C1*h*m*v + C2*h*m + C3*v**2], p = 3.875090624999998e-11, parse trees = 414, valid = False
# -> [C0*m**3*v], p = 0.0008400000000000001, parse trees = 414, valid = False
# -> [C0*h*m + C1*v], p = 0.0009449999999999999, parse trees = 414, valid = False
# -> [C0*h*m*v], p = 0.0031499999999999996, parse trees = 414, valid = False
# -> [C0*h**3*m + C1*h*m + C2*h*v + C3*v], p = 1.2916968749999996e-09, parse trees = 414, valid = False
# -> [C0*h**2*m**2*v + C1*h + C2*m*v + C3*v], p = 1.7222624999999996e-09, parse trees = 414, valid = False
# -> [C0*h + C1*v], p = 0.004725, parse trees = 414, valid = False
# -> [C0*h*m**3*v**3 + C1*m*v], p = 2.5514999999999997e-08, parse trees = 414, valid = False
# -> [C0*m**2], p = 0.028000000000000004, parse trees = 414, valid = False
# -> [C0*h*m], p = 0.020999999999999998, parse trees = 414, valid = False
# -> [C0*h**2*m*v + C1*h*m**2 + C2*h], p = 3.82725e-08, parse trees = 414, valid = False
# -> [C0*h**3*v**2 + C1*h], p = 2.3920312499999994e-06, parse trees = 414, valid = False
# -> [C0*h*m**2*v**2], p = 9.449999999999999e-05, parse trees = 414, valid = False
# -> [C0*h*m**2*v + C1*m*v], p = 5.669999999999998e-06, parse trees = 414, valid = False
# -> [C0*h**3*m**2*v + C1*m], p = 8.504999999999999e-07, parse trees = 414, valid = False
# -> [C0*h**2*m*v], p = 0.0004725, parse trees = 414, valid = False
# -> [C0*h*m*v + C1*h], p = 0.00014175, parse trees = 414, valid = False
# -> [C0*v**2], p = 0.01575, parse trees = 414, valid = False
# -> [C0*m*v + C1*m], p = 0.0012599999999999998, parse trees = 414, valid = False
# -> [C0*h*m**3*v**2 + C1*m], p = 1.1340000000000003e-06, parse trees = 414, valid = False
# -> [C0*h**3*v], p = 0.000354375, parse trees = 414, valid = False
# -> [C0*h*m*v + C1*m**2 + C2*m*v], p = 3.4020000000000004e-07, parse trees = 414, valid = False
# -> [C0*h**3*v + C1*h*v**2 + C2*m], p = 2.1528281249999997e-08, parse trees = 414, valid = False
# -> [C0*h*m**2], p = 0.004200000000000001, parse trees = 414, valid = False
# -> [C0*h**2 + C1*h*m], p = 0.00014175, parse trees = 414, valid = False
# -> [C0*h*m*v + C1*h*v + C2*m], p = 1.2757499999999996e-06, parse trees = 414, valid = False
# -> [C0*h**2*m*v + C1*h], p = 2.1262499999999995e-05, parse trees = 414, valid = False
# -> [C0*h**2*v], p = 0.0023625, parse trees = 414, valid = False
# -> [C0*h**2*m*v + C1*h*m*v + C2*m**2], p = 7.654499999999999e-09, parse trees = 414, valid = False
# -> [C0*h**4*m**2 + C1*h*v + C2*m*v**2], p = 1.2916968749999998e-10, parse trees = 414, valid = False
# -> [C0*h*m**2*v], p = 0.0006299999999999999, parse trees = 414, valid = False
# -> [C0*h**2*v**3 + C1*m], p = 3.1893749999999994e-06, parse trees = 414, valid = False
# -> [C0*h*m + C1*h], p = 0.000945, parse trees = 414, valid = False
# -> [C0*h**4*m**3], p = 2.8349999999999995e-06, parse trees = 414, valid = False
# -> [C0*h**2*v + C1*v], p = 0.00010631249999999999, parse trees = 414, valid = False
# -> [C0*h*m + C1*m**2 + C2*m], p = 9.072000000000001e-07, parse trees = 414, valid = False
# -> [C0*h**2 + C1*h*m**2*v + C2*h*v + C3*m*v + C4*m], p = 1.5500362499999997e-11, parse trees = 414, valid = False
# -> [C0*h*m*v**2], p = 0.0004725, parse trees = 414, valid = False
# -> [C0*h**3*m + C1*m + C2*v**2], p = 1.9136249999999995e-07, parse trees = 414, valid = False
# -> [C0*h**3*m**2*v**2 + C1*m], p = 1.27575e-07, parse trees = 414, valid = False
# -> [C0*h**2 + C1*h*m**2 + C2*h*m + C3*m*v**3 + C4*m], p = 3.100072499999999e-12, parse trees = 414, valid = False
# -> [C0*m**2 + C1*m*v], p = 0.00025200000000000005, parse trees = 414, valid = False
# -> [C0*m**3 + C1*m + C2*v], p = 1.5120000000000001e-05, parse trees = 414, valid = False
# -> [C0*m**2 + C1*m + C2*v**2 + C3*v], p = 2.29635e-08, parse trees = 414, valid = False
# -> [C0*h*m*v + C1*m + C2*v], p = 8.504999999999999e-06, parse trees = 414, valid = False
# -> [C0*m*v**3], p = 0.00047249999999999994, parse trees = 414, valid = False
# -> [C0*h + C1*m**2], p = 0.00126, parse trees = 414, valid = False
# -> [C0*h**2*v**2], p = 0.000354375, parse trees = 414, valid = False
# -> [C0*h**2 + C1*h*v**2 + C2*m*v + C3*v], p = 2.6156861718749992e-12, parse trees = 414, valid = False
# -> [C0*h**2*m*v**2 + C1*h**2*v**2 + C2*h + C3*m], p = 1.3078430859374996e-12, parse trees = 414, valid = False
# -> [C0*m**2 + C1*v], p = 0.0012600000000000003, parse trees = 414, valid = False
# -> [C0*h**3*m*v], p = 7.087499999999999e-05, parse trees = 414, valid = False
# -> [C0*h**3 + C1*h*m], p = 2.12625e-05, parse trees = 414, valid = False
# -> [C0*h**3 + C1*h + C2*m*v], p = 9.568125e-07, parse trees = 414, valid = False
# -> [C0*h*v**2 + C1*m], p = 0.00014174999999999998, parse trees = 414, valid = False
# -> [C0*h + C1*m + C2*v], p = 0.0002835, parse trees = 414, valid = False
# -> [C0*h*v + C1*v], p = 0.00070875, parse trees = 414, valid = False
# -> [C0*h**2*m*v**2 + C1*h + C2*m**3], p = 7.654499999999999e-09, parse trees = 414, valid = False
# -> [C0*h*m*v**3], p = 7.087499999999999e-05, parse trees = 414, valid = False
# -> [C0*h*m**3*v**2], p = 1.8900000000000002e-05, parse trees = 414, valid = False
# -> [C0*h*m**4], p = 0.00016800000000000004, parse trees = 414, valid = False
# -> [C0*h**2*m**3 + C1*m], p = 7.56e-06, parse trees = 414, valid = False
# -> [C0*h*m + C1*h*v**2 + C2*m], p = 1.2757499999999998e-06, parse trees = 414, valid = False
# -> [C0*h*m + C1*m], p = 0.0012599999999999998, parse trees = 414, valid = False
# -> [C0*h*v**2], p = 0.0023625, parse trees = 414, valid = False
# -> [C0*h**2 + C1*h], p = 0.00070875, parse trees = 414, valid = False
# -> [C0*h**2*m*v**2 + C1*h*m], p = 6.378749999999998e-07, parse trees = 414, valid = False
# -> [C0*h**4*m**3*v], p = 4.2525e-07, parse trees = 414, valid = False
# -> [C0*h*v**2 + C1*v], p = 0.00010631249999999999, parse trees = 414, valid = False
# -> [C0*h + C1*m*v], p = 0.0009449999999999999, parse trees = 414, valid = False
# -> [C0*m**3*v**3], p = 1.8900000000000002e-05, parse trees = 414, valid = False
# -> [C0*h*v + C1*h + C2*v], p = 3.189374999999999e-05, parse trees = 414, valid = False
# -> [C0*h**2*v + C1*h**2], p = 1.5946875e-05, parse trees = 414, valid = False
# -> [C0*h + C1*m**3 + C2*m], p = 9.072000000000001e-07, parse trees = 414, valid = False
# -> [C0*h*m*v + C1*m**2], p = 3.7800000000000004e-05, parse trees = 414, valid = False
# -> [C0*h**2*m**3 + C1*m**2 + C2*m], p = 9.072000000000002e-08, parse trees = 414, valid = False
# -> [C0*h**2*m**2*v], p = 9.449999999999999e-05, parse trees = 414, valid = False
# -> [C0*h*m**2 + C1*h*m + C2*m**3], p = 9.072000000000003e-08, parse trees = 414, valid = False
# -> [C0*h**2*m**2], p = 0.0006299999999999999, parse trees = 414, valid = False
# -> [C0*h*m**4*v], p = 2.52e-05, parse trees = 414, valid = False
# -> [C0*h**3], p = 0.0023625, parse trees = 414, valid = False
# -> [C0*h**3*m**4], p = 3.7800000000000002e-06, parse trees = 414, valid = False
# -> [C0*h*m**2*v**3 + C1*v], p = 6.37875e-07, parse trees = 414, valid = False
# -> [C0*m**5*v + C1*m*v], p = 2.7215999999999998e-09, parse trees = 414, valid = False
# -> [C0*h**3*m], p = 0.00047249999999999994, parse trees = 414, valid = False
# -> [C0*h + C1*m*v + C2*m], p = 5.669999999999998e-05, parse trees = 414, valid = False
# -> [C0*h**2*m + C1*h*m], p = 2.8349999999999995e-05, parse trees = 414, valid = False
# -> [C0*m**4*v**3], p = 3.7800000000000002e-06, parse trees = 414, valid = False
# -> [C0*h**2*m + C1*m], p = 0.00018899999999999999, parse trees = 414, valid = False
# -> [C0*m**2*v + C1*v], p = 0.000189, parse trees = 414, valid = False
# -> [C0*h*m**2 + C1*m*v**2], p = 5.67e-06, parse trees = 414, valid = False
# -> [C0*h*m*v + C1*h + C2*m**3], p = 3.402e-07, parse trees = 414, valid = False
# -> [C0*h*v + C1*m**2*v], p = 2.8350000000000005e-05, parse trees = 414, valid = False
# -> [C0*h**2 + C1*h*m*v + C2*h*v], p = 1.4352187499999995e-07, parse trees = 414, valid = False
# -> [C0*h*m**2*v + C1*h*m*v], p = 8.504999999999998e-07, parse trees = 414, valid = False
# -> [C0*h*m + C1*m*v], p = 0.00018899999999999996, parse trees = 414, valid = False
# -> [C0*h**2*m**3], p = 0.000126, parse trees = 414, valid = False
# -> [C0*m**4], p = 0.0011200000000000003, parse trees = 414, valid = False
# -> [C0*h**2 + C1*m], p = 0.0009449999999999999, parse trees = 414, valid = False
# -> [C0*h**2*m**2*v**2], p = 1.4174999999999999e-05, parse trees = 414, valid = False
# -> [C0*h**2*v**2 + C1*h*m*v], p = 4.7840625e-07, parse trees = 414, valid = False
# -> [C0*h**2*m + C1*v**2 + C2*v], p = 9.568125e-07, parse trees = 414, valid = False
# -> [C0*h*v + C1*h + C2*m*v], p = 6.37875e-06, parse trees = 414, valid = False
# -> [C0*h**2*v + C1*h*m], p = 2.12625e-05, parse trees = 414, valid = False
# -> [C0*m**2*v**2], p = 0.0006299999999999999, parse trees = 414, valid = False
# -> [C0*h*m + C1*m**2], p = 0.00025200000000000005, parse trees = 414, valid = False
# -> [C0*h**2*m**4], p = 2.52e-05, parse trees = 414, valid = False
# -> [C0*h**4*m**2], p = 1.4174999999999999e-05, parse trees = 414, valid = False
# -> [C0*h**2*v**3 + C1*m**3 + C2*v], p = 5.740875000000001e-09, parse trees = 414, valid = False
# -> [C0*h*m**5 + C1*h*m + C2*h*v + C3*m**2*v], p = 3.674160000000002e-12, parse trees = 414, valid = False
# -> [C0*h**3 + C1*h*v], p = 1.5946875e-05, parse trees = 414, valid = False
# -> [C0*m**3*v**3 + C1*v**3], p = 1.913625e-08, parse trees = 414, valid = False
# -> [C0*m**2*v**2 + C1*m], p = 3.78e-05, parse trees = 414, valid = False
# -> [C0*h*m**2*v + C1*h*v**2], p = 6.378749999999999e-07, parse trees = 414, valid = False
# -> [C0*h*m**3], p = 0.00084, parse trees = 414, valid = False
# -> [C0*h*m**2*v**3 + C1*m**2], p = 1.7010000000000002e-07, parse trees = 414, valid = False
# -> [C0*h**3*v**2 + C1*m], p = 3.1893749999999994e-06, parse trees = 414, valid = False
# -> [C0*h**2 + C1*h*v + C2*m**2 + C3*v], p = 5.740875e-08, parse trees = 414, valid = False
# -> [C0*m**3*v**3 + C1*m*v**2], p = 2.5515e-08, parse trees = 414, valid = False
# -> [C0*h + C1*m*v**2], p = 0.00014174999999999998, parse trees = 414, valid = False
# -> [C0*h**2*m + C1*h + C2*m], p = 5.102999999999999e-07, parse trees = 414, valid = False
# -> [C0*m*v**4], p = 7.087499999999999e-05, parse trees = 414, valid = False
# -> [C0*h*m**2*v**3 + C1*h], p = 6.37875e-07, parse trees = 414, valid = False
# -> [C0*h**2*m*v + C1*v], p = 2.12625e-05, parse trees = 414, valid = False
# -> [C0*m**2*v**3], p = 9.449999999999999e-05, parse trees = 414, valid = False
# -> [C0*h**3*m*v + C1*h*m], p = 6.378749999999998e-07, parse trees = 414, valid = False
# -> [C0*h*m*v + C1*h*v + C2*h + C3*v], p = 4.305656249999999e-08, parse trees = 414, valid = False
# -> [C0*h**4*v], p = 5.3156249999999994e-05, parse trees = 414, valid = False
# -> [C0*h**2*m*v**3 + C1*h**2*m + C2*h + C3*m*v + C4*v], p = 1.177058777343749e-14, parse trees = 414, valid = False
# -> [C0*v**2 + C1*v], p = 0.00070875, parse trees = 414, valid = False
# -> [C0*h**2*m*v**2 + C1*h*m**3 + C2*h*m], p = 2.2963499999999995e-10, parse trees = 414, valid = False
# -> [C0*h**2*m**5*v + C1*h + C2*m*v + C3*v], p = 1.3778099999999998e-11, parse trees = 414, valid = False
# -> [C0*m**3], p = 0.005600000000000001, parse trees = 414, valid = False
# -> [C0*h*m**2 + C1*h + C2*m], p = 1.1339999999999998e-05, parse trees = 414, valid = False
# -> [C0*h*m**2*v + C1*h*m*v + C2*h + C3*m], p = 1.0333574999999998e-10, parse trees = 414, valid = False
# -> [C0*h + C1*m**4*v], p = 7.560000000000001e-06, parse trees = 414, valid = False
# -> [C0*h*m*v + C1*m*v], p = 2.8349999999999995e-05, parse trees = 414, valid = False
# -> [C0*h*m*v + C1*h + C2*m + C3*v], p = 3.827249999999999e-07, parse trees = 414, valid = False
# -> [C0*m*v**2 + C1*m*v], p = 2.8349999999999995e-05, parse trees = 414, valid = False
# -> [C0*h*v**3], p = 0.000354375, parse trees = 414, valid = False
# -> [C0*h*m*v + C1*m*v**2], p = 4.2524999999999995e-06, parse trees = 414, valid = False
# -> [C0*h**4*v**2], p = 7.973437499999998e-06, parse trees = 414, valid = False
# -> [C0*h*m*v + C1*h*m], p = 2.8349999999999995e-05, parse trees = 414, valid = False
# -> [C0*h*m*v**2 + C1*h*m], p = 4.2524999999999995e-06, parse trees = 414, valid = False
# -> [C0*m**2*v**2 + C1*v], p = 2.8349999999999998e-05, parse trees = 414, valid = False
# -> [C0*m**3*v**2], p = 0.000126, parse trees = 414, valid = False
# -> [C0*h**4], p = 0.000354375, parse trees = 414, valid = False
# -> [C0*h + C1*m**3*v], p = 3.7800000000000004e-05, parse trees = 414, valid = False
# -> [C0*h + C1*m*v**4], p = 3.189375e-06, parse trees = 414, valid = False
# -> [C0*h*v + C1*m**2], p = 0.000189, parse trees = 414, valid = False
# -> [C0*h**2 + C1*h*m**2], p = 2.8349999999999995e-05, parse trees = 414, valid = False
# -> [C0*h**2*v + C1*h*v], p = 1.5946875e-05, parse trees = 414, valid = False
# -> [C0*h**3*v + C1*h*m*v**3 + C2*h + C3*m], p = 2.9063179687499994e-11, parse trees = 414, valid = False
# -> [C0*h*m**2 + C1*m], p = 0.000252, parse trees = 414, valid = False
# -> [C0*h*m**2*v + C1*m], p = 3.78e-05, parse trees = 414, valid = False
# -> [C0*h**4*m + C1*h*m*v], p = 9.568124999999999e-08, parse trees = 414, valid = False
# -> [C0*h*v + C1*v**2], p = 0.0001063125, parse trees = 414, valid = False
# -> [C0*h**3*m**2*v**2], p = 2.1262499999999993e-06, parse trees = 414, valid = False
# -> [C0*h*m + C1*h + C2*m + C3*v], p = 1.1481749999999998e-07, parse trees = 414, valid = False
# -> [C0*h*m**2*v + C1*h*v + C2*h + C3*m**3 + C4*v], p = 2.0667149999999994e-11, parse trees = 414, valid = False
# -> [C0*h*m**2 + C1*h*m*v], p = 5.67e-06, parse trees = 414, valid = False
# -> [C0*m**2*v**4], p = 1.4174999999999997e-05, parse trees = 414, valid = False
# -> [C0*h**4*m*v + C1*h*m*v + C2*h*v + C3*h + C4*m], p = 1.5694117031249994e-14, parse trees = 414, valid = False
# -> [C0*h*m*v + C1*v], p = 0.00014174999999999998, parse trees = 414, valid = False
# -> [C0*h**2*m + C1*h + C2*v], p = 6.37875e-06, parse trees = 414, valid = False
# -> [C0*h**2*v + C1*m*v], p = 2.12625e-05, parse trees = 414, valid = False
# -> [C0*m + C1*v**2], p = 0.0009450000000000001, parse trees = 414, valid = False
# -> [C0*h*v + C1*h + C2*m], p = 4.2525e-05, parse trees = 414, valid = False
# -> [C0*h + C1*m*v + C2*m + C3*v], p = 2.551499999999999e-06, parse trees = 414, valid = False
# -> [C0*h**3*m**5 + C1*m*v], p = 6.804000000000002e-09, parse trees = 414, valid = False
# -> [C0*h**3*v**2], p = 5.3156249999999994e-05, parse trees = 414, valid = False
# -> [C0*h**2*m**2*v + C1*h], p = 4.2525e-06, parse trees = 414, valid = False
# -> [C0*h**2*m*v**2 + C1*h], p = 3.1893749999999994e-06, parse trees = 414, valid = False
# -> [C0*h*m**2*v + C1*h*v], p = 4.2524999999999995e-06, parse trees = 414, valid = False
# -> [C0*h**5*m**2], p = 2.1262499999999998e-06, parse trees = 414, valid = False
# -> [C0*h*m**3*v**3 + C1*h*m**2*v], p = 7.654499999999999e-10, parse trees = 414, valid = False
# -> [C0*h*m + C1*h + C2*v], p = 4.252499999999999e-05, parse trees = 414, valid = False
# -> [C0*m**5*v**2], p = 5.040000000000002e-06, parse trees = 414, valid = False
# -> [C0*h*m*v + C1*m**3], p = 7.5600000000000005e-06, parse trees = 414, valid = False
# -> [C0*h**3 + C1*m*v + C2*m], p = 1.2757499999999998e-06, parse trees = 414, valid = False
# -> [C0*h*m*v**3 + C1*m], p = 4.252499999999999e-06, parse trees = 414, valid = False
# -> [C0*m*v**2 + C1*m], p = 0.00018899999999999999, parse trees = 414, valid = False
# -> [C0*h*m**3 + C1*v], p = 3.7800000000000004e-05, parse trees = 414, valid = False
# -> [C0*h*m**3*v + C1*h + C2*m], p = 3.4020000000000004e-07, parse trees = 414, valid = False
# -> [C0*h**2*m**2 + C1*m**2*v + C2*m], p = 4.082399999999999e-09, parse trees = 414, valid = False
# -> [C0*h**2*m + C1*h], p = 0.00014175, parse trees = 414, valid = False
# -> [C0*m + C1*v**3], p = 0.00014174999999999998, parse trees = 414, valid = False
# -> [C0*h**2*m**2 + C1*m**2], p = 7.560000000000002e-06, parse trees = 414, valid = False
# -> [C0*h*m**4*v**2], p = 3.78e-06, parse trees = 414, valid = False
# -> [C0*h**2*m**4*v**4], p = 1.2757499999999999e-08, parse trees = 414, valid = False
# -> [C0*h**3*v**2 + C1*v], p = 2.3920312499999994e-06, parse trees = 414, valid = False
# -> [C0*h**2*v**2 + C1*v], p = 1.5946875e-05, parse trees = 414, valid = False
# -> [C0*h**2*m**2 + C1*m*v], p = 5.669999999999999e-06, parse trees = 414, valid = False
# -> [C0*h**2*m**5*v], p = 7.560000000000002e-07, parse trees = 414, valid = False
# -> [C0*m**2*v + C1*m*v], p = 3.78e-05, parse trees = 414, valid = False
# -> [C0*h**2*m**2 + C1*h*m*v**2 + C2*m], p = 7.654499999999999e-09, parse trees = 414, valid = False
# -> [C0*h**2*m + C1*v**2], p = 2.1262499999999995e-05, parse trees = 414, valid = False
# -> [C0*h*m**2 + C1*m**2], p = 5.0400000000000005e-05, parse trees = 414, valid = False
# -> [C0*h*m*v**2 + C1*h + C2*m*v**2 + C3*m + C4*v**2], p = 1.1625271874999996e-11, parse trees = 414, valid = False
# -> [C0*h**3*m**4*v**3], p = 1.2757499999999999e-08, parse trees = 414, valid = False
# -> [C0*h*m + C1*m**3 + C2*v], p = 2.268e-06, parse trees = 414, valid = False
# -> [C0*m**2 + C1*m], p = 0.00168, parse trees = 414, valid = False
# -> [C0*h*m**2*v + C1*m**2], p = 7.560000000000001e-06, parse trees = 414, valid = False
# -> [C0*h*m**2 + C1*h*m + C2*h + C3*m], p = 6.123599999999999e-09, parse trees = 414, valid = False
# -> [C0*h**2*v + C1*m], p = 0.00014174999999999998, parse trees = 414, valid = False
# -> [C0*h*m**2 + C1*h*v + C2*h + C3*m**2*v**2 + C4*m + C5*v], p = 9.3002175e-13, parse trees = 414, valid = False
# -> [C0*h*m*v**2 + C1*h*v**2 + C2*m*v], p = 4.3056562499999994e-09, parse trees = 414, valid = False
# -> [C0*h**2*v + C1*h*v**2], p = 2.3920312499999998e-06, parse trees = 414, valid = False
# -> [C0*h*m**3*v**2 + C1*h + C2*m*v**2 + C3*v], p = 5.166787499999999e-11, parse trees = 414, valid = False
# -> [C0*h*m*v + C1*m], p = 0.00018899999999999999, parse trees = 414, valid = False
# -> [C0*h**2 + C1*h*v + C2*m], p = 6.378749999999999e-06, parse trees = 414, valid = False
# -> [C0*h**4*m**2*v], p = 2.1262499999999993e-06, parse trees = 414, valid = False
# -> [C0*h + C1*m**2*v + C2*v], p = 8.505e-06, parse trees = 414, valid = False
# -> [C0*h*m + C1*h + C2*m**2 + C3*m + C4*v], p = 6.200145e-11, parse trees = 414, valid = False
# -> [C0*h**3*m*v**3 + C1*m*v**2 + C2*v], p = 9.687726562499997e-11, parse trees = 414, valid = False
# -> [C0*h**3*m*v**2], p = 1.063125e-05, parse trees = 414, valid = False
# -> [C0*h*m + C1*m*v**2], p = 2.8349999999999995e-05, parse trees = 414, valid = False
# -> [C0*h*v + C1*h + C2*m + C3*v], p = 1.9136249999999994e-06, parse trees = 414, valid = False
# -> [C0*h**4*m**2*v + C1*h], p = 9.568124999999999e-08, parse trees = 414, valid = False
# -> [C0*h*m**2*v + C1*h], p = 2.8349999999999998e-05, parse trees = 414, valid = False
# -> [C0*h**2*m**3*v**2 + C1*h*m], p = 2.5514999999999997e-08, parse trees = 414, valid = False
# -> [C0*h**2*m**2*v**2 + C1*h + C2*m*v**2], p = 8.611312499999997e-10, parse trees = 414, valid = False
# -> [C0*h**2 + C1*m*v], p = 0.00014174999999999998, parse trees = 414, valid = False
# -> [C0*h*v**2 + C1*h*v + C2*m**3 + C3*m + C4*v], p = 6.200145000000001e-12, parse trees = 414, valid = False
# -> [C0*h**3*m**5*v + C1*m**3*v + C2*m**2*v + C3*m], p = 2.645395200000001e-16, parse trees = 414, valid = False
# -> [C0*h**3*m*v**3], p = 1.5946875e-06, parse trees = 414, valid = False
# -> [C0*h**3*m**5*v], p = 1.1340000000000001e-07, parse trees = 414, valid = False
# -> [C0*h*v**2 + C1*h*v + C2*h], p = 7.176093749999999e-07, parse trees = 414, valid = False
# -> [C0*h**2*v + C1*h + C2*v**2], p = 7.176093749999999e-07, parse trees = 414, valid = False
# -> [C0*h*m + C1*h + C2*m], p = 5.669999999999998e-05, parse trees = 414, valid = False
# -> [C0*h*m**2*v**3], p = 1.4174999999999999e-05, parse trees = 414, valid = False
# -> [C0*m**2*v**2 + C1*m*v], p = 5.669999999999999e-06, parse trees = 414, valid = False
# -> [C0*h*m**2*v**2 + C1*h*m*v + C2*m + C3*v], p = 3.4445249999999995e-10, parse trees = 414, valid = False
# -> [C0*h**2*m**4*v**2 + C1*h*v], p = 3.827250000000001e-09, parse trees = 414, valid = False
# -> [C0*h*m**2 + C1*v], p = 0.00018900000000000004, parse trees = 414, valid = False
# -> [C0*h**2*m*v + C1*h*v], p = 3.189375e-06, parse trees = 414, valid = False
# -> [C0*m**5], p = 0.00022400000000000008, parse trees = 414, valid = False
# -> [C0*h**2*m**5*v**3], p = 1.7010000000000005e-08, parse trees = 414, valid = False
# -> [C0*h*v**4 + C1*v], p = 1.0764140624999998e-07, parse trees = 414, valid = False
# -> [C0*h**3*m**4*v + C1*h*v**2 + C2*m], p = 3.444524999999999e-11, parse trees = 414, valid = False
# -> [C0*h**3*m**3], p = 1.8900000000000002e-05, parse trees = 414, valid = False
# -> [C0*h*v**2 + C1*h], p = 0.00010631249999999999, parse trees = 414, valid = False
# -> [C0*h**4*m**7 + C1*h*m*v], p = 6.123600000000002e-12, parse trees = 414, valid = False
# -> [C0*h*v + C1*m*v**2], p = 2.12625e-05, parse trees = 414, valid = False
# -> [C0*h*m**2*v + C1*v], p = 1.27575e-06, parse trees = 414, valid = False
# -> [C0*m**4*v], p = 0.00016800000000000002, parse trees = 414, valid = False
# -> [C0*h**4*m**4 + C1*h], p = 2.5514999999999997e-08, parse trees = 414, valid = False
# -> [C0*h**2*m + C1*h*m**2*v], p = 8.504999999999998e-07, parse trees = 414, valid = False
# -> [C0*h + C1*m**3], p = 0.00025200000000000005, parse trees = 414, valid = False
# -> [C0*h**2 + C1*v], p = 0.00070875, parse trees = 414, valid = False
# -> [C0*h*m*v**2 + C1*m], p = 2.8349999999999995e-05, parse trees = 414, valid = False
# -> [C0*h + C1*v**2 + C2*v], p = 3.189374999999999e-05, parse trees = 414, valid = False
# -> [C0*m**3*v + C1*m], p = 5.0400000000000005e-05, parse trees = 414, valid = False
# -> [C0*h*m + C1*m*v**2 + C2*m], p = 1.7009999999999995e-06, parse trees = 414, valid = False
# -> [C0*h*m**2 + C1*h*v**2], p = 4.2524999999999995e-06, parse trees = 414, valid = False
# -> [C0*h**3 + C1*h**2*v + C2*m], p = 1.43521875e-07, parse trees = 414, valid = False
# -> [C0*h**2*m**2*v**3], p = 2.1262499999999993e-06, parse trees = 414, valid = False
# -> [C0*h**2 + C1*m**2], p = 0.00018900000000000004, parse trees = 414, valid = False
# -> [C0*m*v**2 + C1*m + C2*v], p = 8.504999999999999e-06, parse trees = 414, valid = False
# -> [C0*h**2 + C1*h*v], p = 0.0001063125, parse trees = 414, valid = False
# -> [C0*h**2*m**4 + C1*v**2], p = 1.701e-07, parse trees = 414, valid = False
# -> [C0*m**2*v + C1*m**2], p = 5.0400000000000005e-05, parse trees = 414, valid = False
# -> [C0*h**2*m*v + C1*h*v + C2*m*v], p = 2.8704374999999994e-08, parse trees = 414, valid = False
# -> [C0*h*v + C1*h + C2*m**3*v + C3*m], p = 9.185400000000003e-10, parse trees = 414, valid = False
# -> [C0*h*v + C1*m*v], p = 0.00014175, parse trees = 414, valid = False
# -> [C0*h**3*m**5*v**3 + C1*h*m**2], p = 4.5927e-12, parse trees = 414, valid = False
# -> [C0*h*m*v + C1*h*v], p = 2.1262499999999995e-05, parse trees = 414, valid = False
# -> [C0*h**2 + C1*h*m*v + C2*m + C3*v**2], p = 8.611312499999996e-09, parse trees = 414, valid = False
# -> [C0*m*v**4 + C1*m], p = 4.252499999999999e-06, parse trees = 414, valid = False
# -> [C0*h**3 + C1*m*v**2 + C2*m*v], p = 2.870437499999999e-08, parse trees = 414, valid = False
# -> [C0*h*m*v**4 + C1*h], p = 4.784062499999999e-07, parse trees = 414, valid = False
# -> [C0*h**3*m*v + C1*h + C2*v], p = 1.4352187499999995e-07, parse trees = 414, valid = False
# -> [C0*h**4*v + C1*h*m**2*v], p = 1.4352187499999997e-08, parse trees = 414, valid = False
# -> [C0*h*m*v + C1*m + C2*v**2 + C3*v], p = 5.740874999999999e-08, parse trees = 414, valid = False
# -> [C0*h**4*v**2 + C1*h + C2*v**2], p = 1.6348038574218744e-11, parse trees = 414, valid = False
# -> [C0*h**2 + C1*h*m + C2*h + C3*m**2*v + C4*m], p = 4.133429999999998e-11, parse trees = 414, valid = False
# -> [C0*h + C1*m**2*v + C2*m], p = 1.134e-05, parse trees = 414, valid = False
# -> [C0*m**4*v**4], p = 5.67e-07, parse trees = 414, valid = False
# -> [C0*h*m**3*v**2 + C1*v**2], p = 1.27575e-07, parse trees = 414, valid = False
# -> [C0*h*m*v**2 + C1*h*m + C2*m], p = 1.5308999999999998e-08, parse trees = 414, valid = False
# -> [C0*h**2*m**2 + C1*h**2*m*v**3 + C2*h*m*v**2 + C3*v], p = 2.615686171874999e-14, parse trees = 414, valid = False
# -> [C0*h**2*v**3 + C1*h*m*v**3], p = 1.6146210937499998e-09, parse trees = 414, valid = False
# -> [C0*h**3*v + C1*v], p = 1.5946875e-05, parse trees = 414, valid = False
# -> [C0*h*m**3*v**2 + C1*h*m + C2*h], p = 7.654499999999999e-09, parse trees = 414, valid = False
# -> [C0*h**3 + C1*h*m**4*v + C2*h], p = 1.1481750000000003e-09, parse trees = 414, valid = False
# -> [C0*m*v**2 + C1*v], p = 0.00014174999999999998, parse trees = 414, valid = False
# -> [C0*m*v + C1*v], p = 4.2525e-05, parse trees = 414, valid = False
# -> [C0*h*m**2 + C1*h*m*v**5], p = 2.8704374999999995e-09, parse trees = 414, valid = False
# -> [C0*h*m + C1*m**2*v], p = 3.78e-05, parse trees = 414, valid = False
# -> [C0*h**2*m*v + C1*m**2*v**2], p = 1.2757499999999998e-07, parse trees = 414, valid = False
# -> [C0*h**2*m*v + C1*h**2], p = 3.1893749999999994e-06, parse trees = 414, valid = False
# -> [C0*h*m + C1*m + C2*v], p = 2.5515e-06, parse trees = 414, valid = False
# -> [C0*h**2*m**2 + C1*v], p = 2.8349999999999998e-05, parse trees = 414, valid = False
# -> [C0*h*v**2 + C1*v**2 + C2*v], p = 7.176093749999999e-07, parse trees = 414, valid = False
# -> [C0*h*m**4 + C1*h], p = 7.560000000000003e-06, parse trees = 414, valid = False
# -> [C0*h*v + C1*m*v**3], p = 3.189375e-06, parse trees = 414, valid = False
# -> [C0*h*m*v**4], p = 1.0631249999999998e-05, parse trees = 414, valid = False
# -> [C0*m**2*v + C1*m], p = 4.536e-07, parse trees = 414, valid = False
# -> [C0*h**2*m + C1*m*v], p = 2.8349999999999995e-05, parse trees = 414, valid = False
# -> [C0*h**2*m**4*v], p = 3.78e-06, parse trees = 414, valid = False
# -> [C0*h*m**4 + C1*h*m*v], p = 3.0618e-10, parse trees = 414, valid = False
# -> [C0*h**2*m + C1*h**2*v**2], p = 4.7840625e-07, parse trees = 414, valid = False
# -> [C0*h**2*v + C1*h], p = 0.0001063125, parse trees = 414, valid = False
# -> [C0*m**2 + C1*m*v + C2*m], p = 1.3607999999999999e-07, parse trees = 414, valid = False
# -> [C0*h*m + C1*m**3], p = 5.0400000000000005e-05, parse trees = 414, valid = False
# -> [C0*h**4 + C1*h], p = 1.5946874999999996e-05, parse trees = 414, valid = False
# -> [C0*h*m**3 + C1*m], p = 5.0400000000000005e-05, parse trees = 414, valid = False
# -> [C0*m**2*v**5 + C1*m**2*v**2], p = 5.740875000000001e-10, parse trees = 414, valid = False
# -> [C0*h**2 + C1*h + C2*m], p = 4.2525e-05, parse trees = 414, valid = False
# -> [C0*h*m**3*v + C1*h*m], p = 1.1339999999999999e-06, parse trees = 414, valid = False
# -> [C0*h**4*m*v**2], p = 1.5946874999999995e-06, parse trees = 414, valid = False
# -> [C0*m**3 + C1*v], p = 0.00025200000000000005, parse trees = 414, valid = False
# -> [C0*h*m**4*v + C1*v**2], p = 1.701e-07, parse trees = 414, valid = False
# -> [C0*h**2*m**4*v**2], p = 5.67e-07, parse trees = 414, valid = False
# -> [C0*h*m + C1*h*v**2 + C2*h*v + C3*m], p = 8.611312499999999e-09, parse trees = 414, valid = False
# -> [C0*h**2*v**3 + C1*h*m + C2*m*v], p = 4.3056562499999994e-09, parse trees = 414, valid = False
# -> [C0*h*v + C1*m**2 + C2*m], p = 1.1340000000000002e-05, parse trees = 414, valid = False
# -> [C0*h*m + C1*h*v + C2*m*v], p = 1.2757499999999998e-06, parse trees = 414, valid = False
# -> [C0*h*m**2 + C1*h], p = 0.00018900000000000004, parse trees = 414, valid = False
# -> [C0*h**2*m**5*v**2 + C1*m*v], p = 1.0206e-09, parse trees = 414, valid = False
# -> [C0*h*m*v**2 + C1*v], p = 2.1262499999999995e-05, parse trees = 414, valid = False
# -> [C0*h*m*v**2 + C1*h*v], p = 3.189375e-06, parse trees = 414, valid = False
# -> [C0*h*m*v + C1*h*m + C2*m**2 + C3*m*v**2], p = 4.5926999999999996e-10, parse trees = 414, valid = False
# -> [C0*h**3*m**2*v**5 + C1*h*m*v**2 + C2*m**2 + C3*v], p = 7.847058515624998e-16, parse trees = 414, valid = False
# -> [C0*m**3 + C1*m], p = 0.0003360000000000001, parse trees = 414, valid = False
# -> [C0*h**4*m**2 + C1*h*m*v**2], p = 2.8704374999999995e-09, parse trees = 414, valid = False
# -> [C0*h**2 + C1*h*m*v + C2*v], p = 9.568125e-07, parse trees = 414, valid = False
# -> [C0*h*m*v + C1*h*v**2], p = 3.1893749999999994e-06, parse trees = 414, valid = False
# -> [C0*h*m**3 + C1*m*v**2], p = 1.1339999999999999e-06, parse trees = 414, valid = False
# -> [C0*h*m**3*v], p = 0.000126, parse trees = 414, valid = False
# -> [C0*h*m**2 + C1*h*m*v**2 + C2*m], p = 5.102999999999999e-08, parse trees = 414, valid = False
# -> [C0*m**3*v**4], p = 2.835e-06, parse trees = 414, valid = False
# -> [C0*m**2*v + C1*m*v**2], p = 5.669999999999999e-06, parse trees = 414, valid = False
# -> [C0*m + C1*v**3 + C2*v], p = 6.378749999999998e-06, parse trees = 414, valid = False
# -> [C0*h*m*v + C1*h*m + C2*h], p = 1.2757499999999998e-06, parse trees = 414, valid = False
# -> [C0*m*v**3 + C1*v], p = 2.12625e-05, parse trees = 414, valid = False
# -> [C0*h**2*m**2*v + C1*m**2 + C2*v], p = 5.103e-08, parse trees = 414, valid = False
# -> [C0*m**2 + C1*v**2], p = 0.00018900000000000004, parse trees = 414, valid = False
# -> [C0*h**3*v + C1*h**2*m*v + C2*h*m**3*v + C3*m*v + C4*m], p = 2.092548937499999e-15, parse trees = 414, valid = False
# -> [C0*h*m**5*v], p = 5.040000000000001e-06, parse trees = 414, valid = False
# -> [C0*h**2*m*v + C1*h*m + C2*h], p = 1.9136249999999998e-07, parse trees = 414, valid = False
# -> [C0*h*m + C1*h*v], p = 0.00014174999999999998, parse trees = 414, valid = False
# -> [C0*h*v + C1*m + C2*v], p = 4.252499999999999e-05, parse trees = 414, valid = False
# -> [C0*h*m*v**4 + C1*h*v + C2*m*v + C3*m], p = 3.875090624999998e-11, parse trees = 414, valid = False
# -> [C0*h**2*m**3*v], p = 1.8900000000000002e-05, parse trees = 414, valid = False
# -> [C0*h**2*m**2*v + C1*m], p = 5.67e-06, parse trees = 414, valid = False
# -> [C0*h**3*m*v + C1*m + C2*v], p = 1.9136249999999995e-07, parse trees = 414, valid = False
# -> [C0*h**4*v**2 + C1*v], p = 3.588046874999999e-07, parse trees = 414, valid = False
# -> [C0*h*m**2 + C1*m + C2*v], p = 1.1339999999999998e-05, parse trees = 414, valid = False
# -> [C0*h + C1*v**2], p = 3.189374999999999e-05, parse trees = 414, valid = False
# -> [C0*h**4*v + C1*m], p = 1.9136249999999995e-07, parse trees = 414, valid = False
# -> [C0*h**3*m**6*v**3 + C1*h*m**2 + C2*h*m*v], p = 1.240029e-15, parse trees = 414, valid = False
# -> [C0*h**2*m*v + C1*m], p = 1.7009999999999997e-06, parse trees = 414, valid = False
# -> [C0*h**2*m**2*v**3 + C1*m**2], p = 2.5515e-08, parse trees = 414, valid = False
# -> [C0*h**3*v + C1*h + C2*m + C3*v**2], p = 6.458484374999998e-09, parse trees = 414, valid = False
# -> [C0*h*v**2 + C1*h*v + C2*v], p = 7.176093749999999e-07, parse trees = 414, valid = False
# -> [C0*h*v + C1*h + C2*v**2 + C3*v], p = 2.1528281249999996e-07, parse trees = 414, valid = False
# -> [C0*h*m**5], p = 3.360000000000001e-05, parse trees = 414, valid = False
# -> [C0*h**5*m**4 + C1*h*m*v + C2*h], p = 5.1667874999999994e-12, parse trees = 414, valid = False
# -> [C0*m**5*v + C1*v], p = 1.5120000000000005e-06, parse trees = 414, valid = False
# -> [C0*h + C1*m + C2*v**2], p = 4.2525e-05, parse trees = 414, valid = False
# -> [C0*h**2*m + C1*m*v**2], p = 4.2524999999999995e-06, parse trees = 414, valid = False
# -> [C0*h**3*m + C1*h*m + C2*m*v], p = 3.8272499999999994e-08, parse trees = 414, valid = False
# -> [C0*m**2*v**2 + C1*m + C2*v], p = 1.7009999999999999e-06, parse trees = 414, valid = False
# -> [C0*h**4*m*v], p = 1.063125e-05, parse trees = 414, valid = False
# -> [C0*h**2*m**3 + C1*h*m + C2*v], p = 5.1029999999999994e-08, parse trees = 414, valid = False
# -> [C0*h**2*m**3*v + C1*m], p = 1.134e-06, parse trees = 414, valid = False
# -> [C0*h**2*m**3*v**3], p = 4.2525e-07, parse trees = 414, valid = False
# -> [C0*h**2*m**2*v**2 + C1*h + C2*m], p = 1.0333574999999999e-10, parse trees = 414, valid = False
# -> [C0*h**2*m**3*v**2], p = 2.835e-06, parse trees = 414, valid = False
# -> [C0*h*m**2*v + C1*h*m], p = 5.67e-06, parse trees = 414, valid = False
# -> [C0*h*m**3*v + C1*h*m*v + C2*m + C3*v], p = 4.5927e-10, parse trees = 414, valid = False
# -> [C0*m**2*v**3 + C1*v], p = 8.611312499999997e-09, parse trees = 414, valid = False
# -> [C0*h*v**3 + C1*h + C2*m], p = 9.568125e-07, parse trees = 414, valid = False
# -> [C0*h**3 + C1*m*v], p = 2.12625e-05, parse trees = 414, valid = False
# -> [C0*h + C1*m**2*v**2], p = 2.834999999999999e-05, parse trees = 414, valid = False
# -> [C0*h*m + C1*v**2 + C2*v], p = 6.378749999999999e-06, parse trees = 414, valid = False
# -> [C0*h*v**3 + C1*h], p = 1.5946875e-05, parse trees = 414, valid = False
# -> [C0*h*m*v**2 + C1*h], p = 2.1262499999999995e-05, parse trees = 414, valid = False
# -> [C0*h*m**4 + C1*h*m], p = 1.512e-06, parse trees = 414, valid = False
# -> [C0*h*m*v**2 + C1*m**2 + C2*m*v], p = 5.1029999999999994e-08, parse trees = 414, valid = False
# -> [C0*h + C1*m**4*v**3], p = 1.701e-07, parse trees = 414, valid = False
# -> [C0*h**2*m + C1*m**2*v**2 + C2*m], p = 5.102999999999999e-08, parse trees = 414, valid = False
# -> [C0*h*v**2 + C1*m**2], p = 2.8350000000000005e-05, parse trees = 414, valid = False
# -> [C0*h*m**2*v + C1*h*m**2 + C2*h + C3*m**2 + C4*m], p = 3.6741599999999994e-11, parse trees = 414, valid = False
# -> [C0*m**3*v**5], p = 4.2525e-07, parse trees = 414, valid = False
# -> [C0*h + C1*m*v + C2*v], p = 4.2525e-05, parse trees = 414, valid = False
# -> [C0*h**2 + C1*h + C2*m*v + C3*m + C4*v**2 + C5*v], p = 1.1625271874999999e-10, parse trees = 414, valid = False
# -> [C0*h*m*v**3 + C1*h + C2*m*v], p = 2.8704374999999994e-08, parse trees = 414, valid = False
# -> [C0*h + C1*m*v**2 + C2*v], p = 2.870437499999999e-07, parse trees = 414, valid = False
# -> [C0*h**4*m**3*v**3 + C1*m + C2*v], p = 2.5833937499999995e-11, parse trees = 414, valid = False
# -> [C0*h*m**2 + C1*h + C2*v**2], p = 5.740874999999999e-08, parse trees = 414, valid = False
# -> [C0*h*m**2 + C1*m**2 + C2*v], p = 2.268000000000001e-06, parse trees = 414, valid = False
# -> [C0*h*m**3 + C1*h*m*v], p = 1.1339999999999999e-06, parse trees = 414, valid = False
# -> [C0*h**3*m**2*v + C1*h*m**2], p = 2.5514999999999994e-08, parse trees = 414, valid = False
# -> [C0*h**3*m + C1*m], p = 2.8349999999999995e-05, parse trees = 414, valid = False
# -> [C0*h**2*v + C1*m*v + C2*m], p = 1.2757499999999998e-06, parse trees = 414, valid = False
# -> [C0*h*m + C1*m**2 + C2*m*v], p = 2.2679999999999997e-06, parse trees = 414, valid = False
# -> [C0*h*v**2 + C1*m*v], p = 2.12625e-05, parse trees = 414, valid = False
# -> [C0*h*m*v**2 + C1*m*v**2], p = 6.378749999999998e-07, parse trees = 414, valid = False
# -> [C0*m*v + C1*v**2 + C2*v], p = 6.378749999999999e-06, parse trees = 414, valid = False
# -> [C0*h**2*m**3*v + C1*v], p = 8.505e-07, parse trees = 414, valid = False
# -> [C0*h*m*v + C1*h + C2*m*v**2], p = 1.9136249999999998e-07, parse trees = 414, valid = False
# -> [C0*m*v + C1*v**2], p = 0.00014174999999999998, parse trees = 414, valid = False
# -> [C0*m**3 + C1*m*v], p = 5.0400000000000005e-05, parse trees = 414, valid = False
# -> [C0*h**2*m**2 + C1*m*v + C2*m], p = 3.4019999999999994e-07, parse trees = 414, valid = False
# -> [C0*m**3*v + C1*m*v], p = 7.56e-06, parse trees = 414, valid = False
# -> [C0*h*v + C1*v**3], p = 1.5946875e-05, parse trees = 414, valid = False
# -> [C0*m**3*v + C1*m**2*v + C2*m], p = 9.072000000000002e-08, parse trees = 414, valid = False
# -> [C0*h**3*m**2], p = 9.449999999999999e-05, parse trees = 414, valid = False
# -> [C0*h**3*m**2*v**3 + C1*v], p = 1.4352187499999994e-08, parse trees = 414, valid = False
# -> [C0*h + C1*m**2 + C2*m], p = 7.560000000000001e-05, parse trees = 414, valid = False
# -> [C0*h**2*v**3], p = 5.3156249999999994e-05, parse trees = 414, valid = False
# -> [C0*v**3], p = 0.0023625, parse trees = 414, valid = False
# -> [C0*m**3 + C1*m**2 + C2*m], p = 2.4192000000000004e-07, parse trees = 414, valid = False
# -> [C0*h**2*m + C1*v], p = 0.00014175, parse trees = 414, valid = False
# -> [C0*h**3*m**3*v**2 + C1*h**2*v**2 + C2*h], p = 2.9063179687500003e-12, parse trees = 414, valid = False
# -> [C0*m**2*v**2 + C1*m*v + C2*m + C3*v], p = 1.5308999999999995e-08, parse trees = 414, valid = False
# -> [C0*h**2*m*v + C1*h*m**3*v**2 + C2*m*v], p = 3.444525e-11, parse trees = 414, valid = False
# -> [C0*h**2*m + C1*h*v**2 + C2*m], p = 1.9136249999999998e-07, parse trees = 414, valid = False
# -> [C0*h**4*m**6*v**2 + C1*h*m + C2*m], p = 2.75562e-13, parse trees = 414, valid = False
# -> [C0*h*m**3*v + C1*m*v], p = 1.1339999999999999e-06, parse trees = 414, valid = False
# -> [C0*h*m**3*v**3], p = 2.835e-06, parse trees = 414, valid = False
# -> [C0*h + C1*m**2*v**2 + C2*v], p = 1.27575e-06, parse trees = 414, valid = False
# -> [C0*h**2*m*v + C1*m + C2*v], p = 1.2757499999999998e-06, parse trees = 414, valid = False
# -> [C0*h*v**2 + C1*m*v**3 + C2*m], p = 1.7222625000000004e-09, parse trees = 414, valid = False
# -> [C0*h**2*m**4 + C1*m], p = 1.512e-06, parse trees = 414, valid = False
# -> [C0*h*m**2*v**4], p = 2.1262499999999998e-06, parse trees = 414, valid = False
# -> [C0*h + C1*m**3*v**3], p = 8.505e-07, parse trees = 414, valid = False
# -> [C0*h**5*v**2 + C1*h*m], p = 1.0764140624999997e-08, parse trees = 414, valid = False
# -> [C0*h**2 + C1*m**2 + C2*m], p = 1.1340000000000003e-05, parse trees = 414, valid = False
# -> [C0*h*m + C1*h + C2*m*v + C3*v], p = 3.8272499999999995e-07, parse trees = 414, valid = False
# -> [C0*h**4*v + C1*h**2*v**3], p = 1.2109658203124997e-09, parse trees = 414, valid = False
# -> [C0*m**2*v**5], p = 2.1262499999999998e-06, parse trees = 414, valid = False
# -> [C0*h**2*m + C1*h*m**3], p = 1.134e-06, parse trees = 414, valid = False
# -> [C0*m**2*v + C1*m*v + C2*v], p = 1.7009999999999995e-06, parse trees = 414, valid = False
# -> [C0*m**3*v**2 + C1*m**2*v], p = 2.268e-07, parse trees = 414, valid = False
# -> [C0*h + C1*m**3 + C2*m*v**2], p = 3.402e-07, parse trees = 414, valid = False
# -> [C0*h*m*v**2 + C1*m**2*v], p = 8.504999999999999e-07, parse trees = 414, valid = False
# -> [C0*m*v + C1*m + C2*v], p = 5.669999999999998e-05, parse trees = 414, valid = False
# -> [C0*h**2*m**3 + C1*h**2*m**2*v], p = 5.103e-09, parse trees = 414, valid = False
# -> [C0*h**2 + C1*h*m + C2*m*v + C3*v], p = 3.8750906249999984e-10, parse trees = 414, valid = False
# -> [C0*h**5*v**4], p = 2.6910351562499996e-08, parse trees = 414, valid = False
# -> [C0*h*m**5*v**3], p = 1.1340000000000001e-07, parse trees = 414, valid = False
# -> [C0*h**2*m**2 + C1*h], p = 2.834999999999999e-05, parse trees = 414, valid = False
# -> [C0*h*m**6], p = 6.7200000000000026e-06, parse trees = 414, valid = False
# -> [C0*h*m**3 + C1*h*v**2], p = 8.505e-07, parse trees = 414, valid = False
# -> [C0*h**2*m*v**4 + C1*h*m*v**2 + C2*m**2], p = 3.8750906249999985e-12, parse trees = 414, valid = False
# -> [C0*h**2*m**2 + C1*h**2*m + C2*m + C3*v**2 + C4*v], p = 1.5500362499999997e-11, parse trees = 414, valid = False
# -> [C0*h**2*m*v + C1*h*m + C2*h + C3*v], p = 8.611312499999999e-09, parse trees = 414, valid = False
# -> [C0*h**2 + C1*h*v + C2*h + C3*v], p = 2.1528281249999996e-07, parse trees = 414, valid = False
# -> [C0*h**3*m*v**3 + C1*h**2*m**2*v + C2*h*m*v + C3*m], p = 5.231372343749999e-15, parse trees = 414, valid = False
# -> [C0*m**3*v + C1*v**2], p = 5.670000000000002e-06, parse trees = 414, valid = False
# -> [C0*m + C1*v**4], p = 2.12625e-05, parse trees = 414, valid = False
# -> [C0*h*m + C1*v**2], p = 0.00014175, parse trees = 414, valid = False
# -> [C0*h*m**2 + C1*h*m + C2*v], p = 1.7009999999999997e-06, parse trees = 414, valid = False
# -> [C0*h**3 + C1*v], p = 0.0001063125, parse trees = 414, valid = False
# -> [C0*h**2*m + C1*h*m + C2*h], p = 5.7408749999999995e-08, parse trees = 414, valid = False
# -> [C0*h**2 + C1*v**2], p = 0.0001063125, parse trees = 414, valid = False
# -> [C0*m**4 + C1*m], p = 6.720000000000002e-05, parse trees = 414, valid = False
# -> [C0*m**3 + C1*m*v**2], p = 7.5600000000000005e-06, parse trees = 414, valid = False
# -> [C0*h**3*m + C1*h], p = 2.1262500000000002e-05, parse trees = 414, valid = False
# -> [C0*h**2*m*v**2 + C1*h**2*v], p = 7.176093749999999e-08, parse trees = 414, valid = False
# -> [C0*h**2*v + C1*m**3*v + C2*m**2*v**2], p = 2.2963499999999998e-10, parse trees = 414, valid = False
# -> [C0*h*m + C1*m*v**2 + C2*m*v], p = 2.2963499999999986e-09, parse trees = 414, valid = False
# -> [C0*h**2*v**3 + C1*h], p = 2.3920312499999998e-06, parse trees = 414, valid = False
# -> [C0*h**2*m**3*v**3 + C1*h**2*m**3*v + C2*v], p = 1.5500362500000002e-13, parse trees = 414, valid = False
# -> [C0*h**2 + C1*m**3*v], p = 5.670000000000001e-06, parse trees = 414, valid = False
# -> [C0*m*v**3 + C1*m], p = 2.835e-05, parse trees = 414, valid = False
# -> [C0*h**2*v**3 + C1*h*m*v + C2*m*v + C3*v], p = 2.6156861718749987e-13, parse trees = 414, valid = False
# -> [C0*h*m**3*v + C1*m], p = 7.56e-06, parse trees = 414, valid = False
# -> [C0*h**2*m**4*v + C1*h*v], p = 2.5515e-08, parse trees = 414, valid = False
# -> [C0*h*m**2*v + C1*h*v + C2*m], p = 2.5514999999999995e-07, parse trees = 414, valid = False
# -> [C0*h*v + C1*m**4*v + C2*m**3 + C3*v], p = 1.2247200000000003e-10, parse trees = 414, valid = False

# %%
ED.fit_models()
ED.get_results(3)
# Out:
# Model skipped. More model parameters than allowed (check max constant).
# Model skipped. More model parameters than allowed (check max constant).
# ModelBox: 3 models
# -> [9.69406240942205*h*m + 0.370776019188895*m*v**2 + 0.220167190594566*m*v], p = 2.2963499999999986e-09, parse trees = 414, valid = True, error = 0.3366329783288462, time = 0.7071065902709961
# -> [9.71921810660947*h*m - 0.0967160079307545*m**2 + 0.585980880774924*m*v], p = 2.2679999999999997e-06, parse trees = 414, valid = True, error = 0.3366689070182255, time = 1.0063447952270508
# -> [-0.0150233860470945*h*m*v + 9.74138593192357*h*m + 0.606993685406023*m**2*v - 0.0886948895761669*m + 0.0838821277679951*v], p = 7.440173999999997e-14, parse trees = 414, valid = True, error = 0.3367417046612093, time = 2.3676726818084717

# %% [markdown]
# 1.4. Loti se še naslednjih enačb:
# 1. projekcija na y os pri kroženju $y = r\sin(\omega t)$, kjer je konstanta (*generiraj_krozenje*).
# 2. Lorenzov popravek $\gamma = \sqrt{1 - v^2/c^2}$, kjer je c hitrost svetlobe, približno $3\cdot10^8 m/s$ (*generiraj_lorenz*)
# 3. ploščina pravilnega n-kotnika: $p = na^2/(4 \tan(\pi/n))$ (*generiraj_ploscina*)
#
# Za vsako od enačb napiši gramatiko, ki jo lahko odkrije. Premisli tudi, kakšne verjetnosti produkcij bi bile smiselne. Poskusi čim bolj omejiti prostor enačb, pri čemer naj ima gramatika še vedno vsaj eno rekurzivno pravilo. Gramatike lahko preizkusiš tudi na podatkih, ampak se zavedaj, da bosta enačbi 2 in 3 verjetno preveč kompleksni, da bi jih imeli čas odkriti na vajah.

# %%
gramatika1 = "E -> E '*' F [0.4] | F [0.6] \n"
gramatika1 += "F -> V [0.6] | T '(' M ')' [0.4] \n"
gramatika1 += "T -> 'sin' [0.4] | 'cos' [0.4] | 'tan' [0.2] \n"
gramatika1 += "M -> M '*' V [0.4] | V [0.6] \n"
gramatika1 += "V -> 'r' [0.4] | 't' [0.4] | 'C' [0.2]"
gramatika1 = pg.GeneratorGrammar(gramatika1)

podatki = generiraj_krozenje(100)
ED = pg.EqDisco(data=podatki, 
                sample_size=50,
                lhs_vars=["y"],
                rhs_vars=["r", "t"],
                generator = gramatika1)
ED.generate_models()
# Out:
# ModelBox: 30 models
# -> [r], p = 0.288, parse trees = 19, valid = False
# -> [C0*r*cos(t)], p = 0.00010616832000000001, parse trees = 19, valid = False
# -> [sin(t)], p = 0.04608, parse trees = 19, valid = False
# -> [r*tan(t)], p = 0.00110592, parse trees = 19, valid = False
# -> [cos(C0*r*t)*tan(r)], p = 2.264924160000001e-06, parse trees = 19, valid = False
# -> [r*t], p = 0.041471999999999995, parse trees = 19, valid = False
# -> [t*cos(t)], p = 0.00221184, parse trees = 19, valid = False
# -> [t], p = 0.288, parse trees = 19, valid = False
# -> [t*cos(r)], p = 0.00221184, parse trees = 19, valid = False
# -> [cos(r)], p = 0.02304, parse trees = 19, valid = False
# -> [t*sin(C0*r)], p = 0.00017694720000000007, parse trees = 19, valid = False
# -> [C0*cos(C1*t)], p = 1.4155776000000007e-05, parse trees = 19, valid = False
# -> [sin(r)], p = 0.02304, parse trees = 19, valid = False
# -> [r*sin(r)*cos(t)], p = 3.3973862400000006e-05, parse trees = 19, valid = False
# -> [t**2], p = 0.013824, parse trees = 19, valid = False
# -> [C0*r*sin(r)], p = 0.00010616832000000001, parse trees = 19, valid = False
# -> [C0*cos(r)], p = 0.00110592, parse trees = 19, valid = False
# -> [C0*r*sin(r**2)*tan(r**3)], p = 7.879497908047428e-15, parse trees = 19, valid = False
# -> [C0*sin(C1*t)], p = 8.847360000000003e-05, parse trees = 19, valid = False
# -> [C0*r**2*cos(C1*r*t**2)], p = 2.0873541058560008e-08, parse trees = 19, valid = False
# -> [tan(C0*r*t**2)], p = 2.359296000000001e-05, parse trees = 19, valid = False
# -> [C0*t*cos(t)], p = 1.6986931200000003e-05, parse trees = 19, valid = False
# -> [r*t**2], p = 0.001327104, parse trees = 19, valid = False
# -> [C0*r*cos(C1*r*t)], p = 1.0871635968000005e-07, parse trees = 19, valid = False
# -> [tan(r)], p = 0.01152, parse trees = 19, valid = False
# -> [r*sin(C0*r)*cos(r*t)], p = 4.3486543872000034e-07, parse trees = 19, valid = False
# -> [r*cos(t)], p = 0.00221184, parse trees = 19, valid = False
# -> [C0*t**2*sin(r*t**2)*tan(t**2)*tan(C1*r*t**2)], p = 4.0343029289202855e-16, parse trees = 19, valid = False
# -> [sin(t**2)], p = 0.003686400000000001, parse trees = 19, valid = False
# -> [cos(r*t)], p = 0.003686400000000001, parse trees = 19, valid = False

# %%
gramatika2 = "E -> E '+' F [0.2] | E '-' F [0.2] | F [0.6] \n"
gramatika2 += "F -> F '*' T [0.2] | F '/' T [0.2] | T [0.6] \n"
gramatika2 += "T -> R [0.3] | V [0.4] | 'C' [0.3] \n"
gramatika2 += "R -> '(' E ')' [0.3] | 'sqrt' '(' E ')' [0.3] | 'exp' '(' E ')' [0.2] | 'log' '(' E ')' [0.2]\n"
gramatika2 += "V -> 'v' [1.0]"
gramatika2 = pg.GeneratorGrammar(gramatika2)

podatki = generiraj_krozenje(100)
ED = pg.EqDisco(data=podatki, 
                sample_size=50,
                lhs_vars=["gamma"],
                rhs_vars=["v"],
                generator = gramatika2)
ED.generate_models()
# Out:
# ModelBox: 28 models
# -> [C0*v**2], p = 8.062156800000003e-08, parse trees = 22, valid = False
# -> [log(C0 + v - exp(C1*v))], p = 2.5076532510719993e-11, parse trees = 22, valid = False
# -> [C0*v], p = 0.00864, parse trees = 22, valid = False
# -> [v], p = 0.288, parse trees = 22, valid = False
# -> [sqrt(C0*v + v)], p = 8.062156799999999e-07, parse trees = 22, valid = False
# -> [C0 - sqrt(v)], p = 0.00016796159999999996, parse trees = 22, valid = False
# -> [C0*v + v**2], p = 1.07495424e-06, parse trees = 22, valid = False
# -> [C0*exp(C1*v*log(C2 + C3*exp(C4*exp(-v)/log(v*(C5 + v)**(1/4)*exp(C6*v)*log(C7*log(C8*sqrt(v)*sqrt(log(C20 + C9*v/log(C10*exp(C11 + C12*(C13/(C14 - sqrt(C15*v)/v) + v)/v + sqrt(C16 + C17*(C18*v + C19 + v)/sqrt(v) + 2*v)/v)))))) + exp(C21*log(v**(1/4)))) - v)/v)) + log(v)], p = 8.83069421835006e-140, parse trees = 22, valid = False
# -> [C0 + v], p = 0.005184013060694015, parse trees = 22, valid = False
# -> [C0/v], p = 0.00864, parse trees = 22, valid = False
# -> [v/log(v**2)], p = 1.9906559999999997e-05, parse trees = 22, valid = False
# -> [sqrt(C0 + v**2*(C1 + v) + v - log(C2/v)*log(exp(v)))], p = 3.520656997884769e-25, parse trees = 22, valid = False
# -> [C0*exp(2*v) + C1 + sqrt(C2*sqrt(C3/v) + v**2/log(C4*v + C5 - v**2 - v - log(C6*v/sqrt(C7 + v/sqrt(C10/(v*(sqrt(v) - log(C11*v))) + C8*v**(3/2) + C9*v + v)))) - v + exp(C12*v + C13/v + sqrt(v) + sqrt(C14*sqrt(C15*v**4)))) + log(v)], p = 1.651523812613037e-109, parse trees = 22, valid = False
# -> [sqrt(v)*exp(sqrt(C0*log(C1*v**2*(C2*exp(C3*v + C4) + C5)/log(2*v)) + C6 + sqrt(C7/log(C12/v**2 + C8*v/log(2*v) + C9/(C10*sqrt(v) + C11 + v) + v - v/(C13 + v) + (C14 - exp(sqrt(C15 + exp(C16*v + v + exp(v))**(1/8))))*exp(sqrt(C17*v)/log(C18 + v))) + v) + sqrt(C19*v*sqrt(2*v + log(C20*v) + E) + v*(C21 - v + sqrt(C22*v + C23))))) + 1], p = 7.016629669437789e-172, parse trees = 22, valid = False
# -> [C0*v**2*sqrt(C1*(C2*v + C3*sqrt(C4 + v) + C5 + C6/(C7*v + C8) + C9/v + v + log(C10*exp(v) + C11 + v/log(C12 + sqrt(C13*v + v) + sqrt(exp(C14*v*(C15*v**3 + C16 + C17/v)))) + sqrt(C18/v))) + C19 + v**2 + v) + v], p = 1.1374829565825536e-116, parse trees = 22, valid = False
# -> [C0 + sqrt(C1/sqrt(C2 - v*exp(C3*v - v - exp(C4*v + C5))) + v)], p = 4.889801385951072e-24, parse trees = 22, valid = False
# -> [sqrt(C0*log(v)/v - v**2)], p = 8.187922952619753e-17, parse trees = 22, valid = False
# -> [exp(v)], p = 0.0031104, parse trees = 22, valid = False
# -> [C0*v + C1/v**2], p = 1.9906560000000003e-06, parse trees = 22, valid = False
# -> [log(log(C0*v**2))], p = 3.2248627199999995e-07, parse trees = 22, valid = False
# -> [C0 + C1*log(C2 - v)/v - v], p = 6.499837226778625e-14, parse trees = 22, valid = False
# -> [C0*v + C1 + v], p = 1.4929919999999999e-05, parse trees = 22, valid = False
# -> [C0*v - v*(C1 + v)*log(C2*exp(C3*v))], p = 2.5035783096069485e-28, parse trees = 22, valid = False
# -> [C0*exp(C1*v*sqrt(C2*(C3 - v**2)*log(exp(C11 + C4*exp(C5*v*sqrt(C6*sqrt(C7*sqrt(C8*v)/log(v))/v + 1) + C9*v + v*(C10 - v) + 2*v)/log(v))/(C12*v*exp(C13*v**2 + C14) + v**2)) - v))/log(v)], p = 5.826812663399035e-111, parse trees = 22, valid = False
# -> [C0*v**2 + v**(1/4) + v - exp(C1*v + C2)], p = 1.347806247344815e-16, parse trees = 22, valid = False
# -> [v*exp(-v)], p = 1.5925248000000006e-06, parse trees = 22, valid = False
# -> [C0*v + C1 + v - exp(v)], p = 4.733037027712933e-17, parse trees = 22, valid = False
# -> [C0 + sqrt(v)], p = 1.0749542400000001e-06, parse trees = 22, valid = False

# %% [markdown]
# ## 2. Preštevanje dreves in verjetnosti
#
# Za linearno gramatiko iz 1.2 ter vsako od gramatik iz 1.4. nariši:
# 1. graf števila dreves z dano višino
# 2. graf verjetnosti vseh dreves do vključno dane višine
#
# Če želiš, lahko sam implementiraš rekurzivne enačbe s predavanj. Alternativno lahko uporabiš ProGED-ovi metodi "grammar.count_trees" in "grammar.count_coverage". Obema je treba podati začetni neterminalni simbol, ki mora biti objekt nltk.Nonterminal.

# %%
from nltk import Nonterminal
import matplotlib.pyplot as plt

grammar = "E -> E '+' V [0.6] | V [0.4]\n"
grammar += "V -> 'x1' [0.33] | 'x2' [0.67]"
grammar = pg.GeneratorGrammar(grammar)

hji = list(range(1,11))
drevesa = [grammar.count_trees(Nonterminal("E"), h) for h in range(1, 11)]
verjetnost = [grammar.count_coverage(Nonterminal("E"), h) for h in range(1, 11)]

# %%
fig, ax = plt.subplots(1, 2, figsize=(8,3))
ax[0].plot(hji, drevesa)
ax[0].set_xlabel("h (visina drevesa)")
ax[0].set_ylabel("stevilo dreves")

ax[1].plot(hji, verjetnost)
ax[1].set_xlabel("h (visina drevesa)")
ax[1].set_ylabel("verjetnost vseh do vklucno h")
# Out:
# Text(0, 0.5, 'verjetnost vseh do vklucno h')

# %% [markdown]
# ## 3. Merske enote
#
# Upoštevanje predznanja o merskih enotah spremenljivk nam pogosto lahko močno zmanjša prostor enačb.
# ProGED nam to omogoča preko formalizma atributnih gramatik, ki jih pretvorimo v navadne konteksno-neodvisne gramatike. Za pogoste tipe gramatik ProGED že implementira njihove dimenzijsko-pravilne različice.
# Enote predstavimo z vektorji v izbrani bazi osnovnih enot (recimo SI).
#
# 3.1 Poglej si spodnji primer za Newtonov zakon ter dopolni manjkajoče!
#
# Plonkec iz osnovne šole:
# - Newtonov zakon $ F=m a$
# - F je sila, z enoto kg*m/s^2
# - m je masa, z enoto kg
# - a je pospešek, z enoto m/s^2

# %%
from ProGED.generators.dimensions import construct_dimensional_polynomial_grammar

podatki = generiraj_newton(100)

spremenljivke = ["m", "a"]
simboli_enot = ["m", "s", "kg"]
enote_na_desni = [[0,0,1], [1,-2,0]] # m, kg*m/s^2
enota_na_levi = [1,-2,1]

grammar = construct_dimensional_polynomial_grammar(variables = spremenljivke,
                                        units = enote_na_desni,
                                        target_variable_unit = enota_na_levi,
                                        unit_symbols = simboli_enot)

grammar
# Out:
# Grammar with 24 productions (start state = P_m1s-2kg1)
#     P_m1s-2kg1 -> P_m1s-2kg1 '+' M_m1s-2kg1 [0.4]
#     P_m1s-2kg1 -> M_m1s-2kg1 [0.6]
#     P_m0s0kg1 -> P_m0s0kg1 '+' M_m0s0kg1 [0.4]
#     P_m0s0kg1 -> M_m0s0kg1 [0.6]
#     P_m1s-2kg0 -> P_m1s-2kg0 '+' M_m1s-2kg0 [0.4]
#     P_m1s-2kg0 -> M_m1s-2kg0 [0.6]
#     P_m0s0kg0 -> P_m0s0kg0 '+' M_m0s0kg0 [0.4]
#     P_m0s0kg0 -> M_m0s0kg0 [0.6]
#     M_m1s-2kg1 -> M_m1s-2kg1 '*' V_m0s0kg0 [0.2]
#     M_m1s-2kg1 -> M_m0s0kg0 '*' V_m1s-2kg1 [0.2]
#     M_m1s-2kg1 -> M_m0s0kg1 '*' V_m1s-2kg0 [0.2]
#     M_m1s-2kg1 -> M_m1s-2kg0 '*' V_m0s0kg1 [0.2]
#     M_m1s-2kg1 -> V_m1s-2kg1 [0.2]
#     M_m0s0kg1 -> M_m0s0kg1 '*' V_m0s0kg0 [0.333333]
#     M_m0s0kg1 -> M_m0s0kg0 '*' V_m0s0kg1 [0.333333]
#     M_m0s0kg1 -> V_m0s0kg1 [0.333333]
#     M_m1s-2kg0 -> M_m1s-2kg0 '*' V_m0s0kg0 [0.333333]
#     M_m1s-2kg0 -> M_m0s0kg0 '*' V_m1s-2kg0 [0.333333]
#     M_m1s-2kg0 -> V_m1s-2kg0 [0.333333]
#     M_m0s0kg0 -> M_m0s0kg0 '*' V_m0s0kg0 [0.4]
#     M_m0s0kg0 -> V_m0s0kg0 [0.4]
#     M_m0s0kg0 -> 'C' [0.2]
#     V_m0s0kg1 -> 'm' [1.0]
#     V_m1s-2kg0 -> 'a' [1.0]

# %% [markdown]
# Vidimo, da ima gramatika veliko več simbolov in produkcij, kot tiste, ki smo jih pisali na roko. Zdaj uporabimo EqDisco in zgenerirajmo množico enačb.

# %%
ED = pg.EqDisco(data=podatki, 
                lhs_vars=["F"],
                rhs_vars=["m", "a"],
                sample_size=10,
                generator = grammar)

ED.generate_models()
# Out:
# ModelBox: 2 models
# -> [a*m], p = 0.04, parse trees = 29, valid = False
# -> [2*a*m], p = 0.0010666666666666667, parse trees = 29, valid = False

# %% [markdown]
# 3.2. Poglejmo še pod krov, torej atributno gramatiko, ki izraža pravila za računanje z merskimi enotami. Oglej si spodnjo atributno gramatiko za dimenzijsko-pravilne polinome ter premisli, kako bi napisal dimenzijsko-pravilno atributno verzijo gramatik, ki si jih sestavil v nalogi 1.4.

# %%
from ProGED.generators.dimensions import dimensional_attribute_grammar_to_pcfg
from nltk import PCFG

prods = []
prods += [["P -> P '+' M", 0.4, ["uP1 - uP2", "uP1 - uM1"]]]
prods += [["P -> M", 0.6, ["uP1 - uM1"]]]
prods += [["M -> M '*' V", 0.4, ["-uM1 + uM2 + uV1"]]]
prods += [["M -> V", 0.4, ["uM1 - uV1"]]]
prods += [["M -> 'C'", 0.2, ["uM1"]]]

pcfg_start, pcfg_prods = dimensional_attribute_grammar_to_pcfg(prods, 
                                                               spremenljivke, 
                                                               enote_na_desni, 
                                                               enota_na_levi, 
                                                               append_vars = True, 
                                                               unit_symbols = simboli_enot)
grammar = pg.GeneratorGrammar(PCFG(pcfg_start, pcfg_prods))
grammar
# Out:
# Grammar with 24 productions (start state = P_m1s-2kg1)
#     P_m1s-2kg1 -> P_m1s-2kg1 '+' M_m1s-2kg1 [0.4]
#     P_m1s-2kg1 -> M_m1s-2kg1 [0.6]
#     P_m0s0kg1 -> P_m0s0kg1 '+' M_m0s0kg1 [0.4]
#     P_m0s0kg1 -> M_m0s0kg1 [0.6]
#     P_m1s-2kg0 -> P_m1s-2kg0 '+' M_m1s-2kg0 [0.4]
#     P_m1s-2kg0 -> M_m1s-2kg0 [0.6]
#     P_m0s0kg0 -> P_m0s0kg0 '+' M_m0s0kg0 [0.4]
#     P_m0s0kg0 -> M_m0s0kg0 [0.6]
#     M_m1s-2kg1 -> M_m1s-2kg1 '*' V_m0s0kg0 [0.2]
#     M_m1s-2kg1 -> M_m0s0kg0 '*' V_m1s-2kg1 [0.2]
#     M_m1s-2kg1 -> M_m0s0kg1 '*' V_m1s-2kg0 [0.2]
#     M_m1s-2kg1 -> M_m1s-2kg0 '*' V_m0s0kg1 [0.2]
#     M_m1s-2kg1 -> V_m1s-2kg1 [0.2]
#     M_m0s0kg1 -> M_m0s0kg1 '*' V_m0s0kg0 [0.333333]
#     M_m0s0kg1 -> M_m0s0kg0 '*' V_m0s0kg1 [0.333333]
#     M_m0s0kg1 -> V_m0s0kg1 [0.333333]
#     M_m1s-2kg0 -> M_m1s-2kg0 '*' V_m0s0kg0 [0.333333]
#     M_m1s-2kg0 -> M_m0s0kg0 '*' V_m1s-2kg0 [0.333333]
#     M_m1s-2kg0 -> V_m1s-2kg0 [0.333333]
#     M_m0s0kg0 -> M_m0s0kg0 '*' V_m0s0kg0 [0.4]
#     M_m0s0kg0 -> V_m0s0kg0 [0.4]
#     M_m0s0kg0 -> 'C' [0.2]
#     V_m0s0kg1 -> 'm' [1.0]
#     V_m1s-2kg0 -> 'a' [1.0]
