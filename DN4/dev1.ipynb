# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Linearna regresija

# %%
def linearna_regresija(X, y, meja=1e-2):
    imena = X.columns
    beta = np.linalg.pinv(X.T.dot(X)).dot(X.T).dot(y)

    izraz = ""
    for i,b in enumerate(beta):
        if b > meja:
            if len(izraz) > 0:
                izraz += " + "
            izraz +=  f"{b:.3f}*{imena[i]}"
    return izraz

# %%
data = pd.read_csv('DN4_1_podatki.csv')

X = data.drop('Q', axis=1)
Y = data['Q']

f = linearna_regresija(X, Y, meja=1e-5)
print(f)
# Out:
# 0.075*Tw

# %%
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(3)
Xp = poly.fit_transform(X)
imena_stolpcev = poly.get_feature_names_out()
Xp = pd.DataFrame(Xp, columns=imena_stolpcev)

fp = linearna_regresija(Xp, Y, meja=1e-1)
print(fp)
# Out:
# 1.163*eta + 0.151*Tw theta + 0.194*theta^2 + 0.550*theta^2 eta + 0.311*eta^3

# %% [markdown]
# Rige regresija

# %%
def ridge_regresija(X, y, lam=1, meja=1e-2):
    imena = X.columns
    beta = np.linalg.pinv(X.T.dot(X) + lam*np.identity(X.shape[1])).dot(X.T).dot(y)

    izraz = ""
    for i,b in enumerate(beta):
        if b > meja:
            if len(izraz) > 0:
                izraz += " + "
            izraz +=  f"{b:.3f}*{imena[i]}"
    return izraz

# %%
fr = ridge_regresija(Xp, Y, lam=0.5)
print(fr)
# Out:
# 0.048*Ta + 0.129*eta + 0.142*Tw theta + 0.053*Ta eta + 0.148*theta^2 + 0.123*eta^2 + 0.010*Tw theta eta + 0.045*Tw eta^2 + 0.051*Ta theta^2 + 0.461*theta^2 eta + 0.178*eta^3

# %% [markdown]
# Lasso

# %%
from scipy.optimize import minimize
def lasso_regresija(X, y, lam=1, meja=1e-2):
    imena = X.columns

    def f(beta):
        yhat = X.dot(beta)
        return np.sum((yhat-y)**2) + lam*np.sum(np.abs(beta))
    beta = minimize(f, np.random.random(X.shape[1]))["x"]
    
    izraz = ""
    for i,b in enumerate(beta):
        if b > meja:
            if len(izraz) > 0:
                izraz += " + "
            izraz +=  f"{b:.3f}*{imena[i]}"
    return izraz

# %%
fl = lasso_regresija(Xp, Y, lam=1)
print(fl)
# Out:
# 0.080*Ta + 0.130*Tw theta + 0.040*Ta eta + 0.109*theta^2 + 0.040*Tw eta^2 + 0.051*Ta theta^2 + 0.013*theta^3 + 0.435*theta^2 eta

# %% [markdown]
# Bacon

# %%
def bacon(df, max_iter=20):
    for iteracija in range(max_iter):
        stolpci = list(df.columns)
        df_array = np.array(df)
        # ocenimo, ali obstaja konstanta
        sig = np.std(df_array, axis=0)
        # testirajmo se trivialnost
        if min(sig) < 10 ** -12:  # pazimo na skalo?
            break
        # izracunajmo vrstne rede, najdemo korelacije med njimi
        vrstni_redi = np.array(df.rank(axis=0)).T
        korelacije = np.corrcoef(vrstni_redi)  # korelacije[i, j]
        n = korelacije.shape[0]
        korelacije = [(abs(korelacije[i, j]), (i, j), korelacije[i, j] < 0) for i in range(n) for j in range(i + 1, n)]
        korelacije.sort(reverse=True)
        for kakovost, (i, j), je_mnozenje in korelacije:
            if je_mnozenje:
                ime_novega = f"({stolpci[i]}) * ({stolpci[j]})"
                vrednosti_novega = df_array[:, i] * df_array[:, j]
            else:
                ime_novega = f"({stolpci[i]}) / ({stolpci[j]})"
                vrednosti_novega = df_array[:, i] / df_array[:, j]
            if ime_novega not in stolpci:
                df[ime_novega] = vrednosti_novega
                break
    # najdemo "konstanto"
    df_array = np.array(df)
    sig = np.std(df_array, axis=0)
    i = np.argmin(sig)
    const = np.mean(df_array[:, i])
    print(f"{const:.5e} = {df.columns[i]} (napaka: {sig[i]})")

# %%
podatki = data
print(data.columns)
bacon(podatki)
# Out:
# Index(['Q', 'Tw', 'Ta', 'theta', 'eta'], dtype='object')
# 1.00000e+00 = ((Tw) / (Ta)) / ((Q) / ((Q) / ((Tw) / (Ta)))) (napaka: 4.213000162292041e-17)

# %% [markdown]
# PySR

# %%
from pysr import PySRRegressor
import sympy 

model = PySRRegressor(
    niterations=1000,  # < Increase me for better results
    binary_operators=["+", "*", "-", "/"],
    unary_operators=[
        "cos",
        "sin",
        "inv(x) = 1/x",
        "abs",
        "square",
        "cube",
        "cos2(x)=cos(x)^2",
        "sin2(x)=sin(x)^2"
        # ^ Custom operator (julia syntax)
    ],
    extra_sympy_mappings={"inv": lambda x: 1 / x,
                          "cos2": lambda x: sympy.cos(x)**2,
                          "sin2": lambda x: sympy.sin(x)**2},
    # ^ Define operator for SymPy as well
    loss="loss(prediction, target) = (prediction - target)^2",
    # ^ Custom loss function (julia syntax)
    timeout_in_seconds=60 * 5,
)

# %%
model.fit(X, Y)
# Out:
# /Users/vitorozman/Documents/School/Master/1.Letnik/ML/Advanced_ML/venv/lib/python3.11/site-packages/pysr/sr.py:1770: UserWarning: The discovered expressions are being reset. Please set `warm_start=True` if you wish to continue to start a search where you left off.
#   warnings.warn(
# /Users/vitorozman/Documents/School/Master/1.Letnik/ML/Advanced_ML/venv/lib/python3.11/site-packages/pysr/sr.py:1296: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Started!
#
# Expressions evaluated per second: 2.690e+05
# Head worker occupation: 6.5%
# Progress: 591 / 15000 total iterations (3.940%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.150e+00  3.109e-07  0.6830067
# 2           1.026e+00  1.144e-01  sin(theta)
# 4           9.466e-01  4.011e-02  cos2(Ta / Tw)
# 5           6.005e-01  4.551e-01  ((Tw + -21.53733) / Ta)
# 6           5.398e-01  1.066e-01  ((cube(Tw) * 0.00025319468) / Ta)
# 7           5.158e-01  4.534e-02  (((Tw - 12.057189) / Ta) - eta)
# 8           3.226e-01  4.695e-01  (((Tw - Ta) * sin(theta)) / 12.2925205)
# 9           1.624e-01  6.862e-01  square(((Tw - Ta) * sin(theta)) / -16.332458)
# 10          1.436e-01  1.229e-01  square(((Tw - Ta) * sin(sin(theta))) / 14.23498)
# 11          1.364e-01  5.130e-02  square(((Tw - Ta) * sin(sin(sin(theta)))) / 12.82538)
# 12          1.161e-01  1.613e-01  square((((Tw - Ta) * sin(theta)) * cos(eta)) / -13.29026)
# 13          4.613e-02  9.231e-01  square((((Tw - Ta) * sin(sin(theta))) * cos(eta)) / 12.512008)
# 14          4.403e-02  4.674e-02  square((((Tw - Ta) * sin(sin(sin(theta)))) * cos(eta)) / 10.69...
#                                   7475)
# 15          2.854e-02  4.336e-01  square((((Tw - Ta) * sin(sin(sin(sin(theta))))) * cos(eta)) / ...
#                                   -10.336159)
# 17          2.093e-02  1.551e-01  square(abs((((Tw - Ta) * sin(sin(sin(theta)) - -0.140551)) * c...
#                                   os(eta)) / -12.539546))
# 18          2.052e-02  1.971e-02  square((((Tw - Ta) * sin(sin(sin(theta) - -0.140551))) * cos(e...
#                                   ta)) / (-12.539546 - -0.5199816))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.670e+05
# Head worker occupation: 7.5%
# Progress: 1159 / 15000 total iterations (7.727%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.150e+00  3.109e-07  0.6830067
# 2           1.026e+00  1.144e-01  sin(theta)
# 3           1.016e+00  9.673e-03  (Tw * 0.020950798)
# 4           9.466e-01  7.054e-02  cos2(Ta / Tw)
# 5           5.717e-01  5.043e-01  ((Tw - Ta) / 17.734062)
# 6           4.298e-01  2.852e-01  square((Tw - Ta) / 21.881804)
# 8           3.159e-01  1.539e-01  (((Tw - Ta) * sin(theta)) / 11.414657)
# 9           1.321e-01  8.722e-01  (square((Tw - Ta) / -16.927153) * sin(theta))
# 11          1.111e-01  8.645e-02  (square(((Tw - eta) - Ta) / -16.927153) * sin(theta))
# 12          7.235e-02  4.289e-01  square((((Tw - Ta) * sin(theta)) * cos(eta)) / 14.483347)
# 13          4.532e-02  4.677e-01  square((((Tw - Ta) * sin(sin(theta))) * cos(eta)) / -12.369491...
#                                   )
# 14          3.582e-02  2.353e-01  (square(((Tw - Ta) * sin(sin(sin(theta)))) / 11.338953) * cos2...
#                                   (eta))
# 15          2.573e-02  3.309e-01  square((((Tw - Ta) * sin(sin(theta) - -0.15837784)) * cos(eta)...
#                                   ) / 14.176301)
# 16          2.093e-02  2.066e-01  square((((Tw - Ta) * sin(sin(sin(theta)) - -0.140551)) * cos(e...
#                                   ta)) / -12.539546)
# 17          1.989e-02  5.057e-02  square((((Tw - Ta) * sin(sin(theta) - inv(sin(-0.1548614)))) *...
#                                    cos(eta)) / 14.176301)
# 19          1.791e-02  5.245e-02  square(((((Tw - Ta) * sin(sin(sin(theta)) - -0.140551)) * cos(...
#                                   sin(eta))) - eta) / -12.539546)
# 20          1.790e-02  9.266e-04  square(((((Tw - Ta) * sin(sin(sin(theta)) - sin(-0.140551))) *...
#                                    cos(sin(eta))) - eta) / -12.539546)
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.710e+05
# Head worker occupation: 7.4%
# Progress: 1768 / 15000 total iterations (11.787%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.150e+00  3.109e-07  0.6830067
# 2           1.026e+00  1.144e-01  sin(theta)
# 3           1.010e+00  1.571e-02  (Tw * 0.019040454)
# 4           9.466e-01  6.451e-02  cos2(Ta / Tw)
# 5           5.717e-01  5.043e-01  ((Tw - Ta) / 17.734062)
# 6           4.298e-01  2.852e-01  square((Tw - Ta) / 21.881804)
# 8           3.159e-01  1.539e-01  (((Tw - Ta) * sin(theta)) / 11.414657)
# 9           1.251e-01  9.264e-01  (square((Tw - Ta) / 17.496258) * sin(theta))
# 11          1.001e-01  1.113e-01  (square((Tw - Ta) / (-16.927153 - eta)) * sin(theta))
# 12          4.080e-02  8.979e-01  ((square((Tw - Ta) / -16.18915) * cos(eta)) * sin(theta))
# 14          3.408e-02  9.003e-02  square((((Tw - Ta) * sin(sin(sin(theta)))) * cos(eta)) / 11.02...
#                                   6156)
# 15          1.982e-02  5.417e-01  square((((Tw - Ta) * sin(sin(theta) - -0.20433131)) * cos(eta)...
#                                   ) / 14.176301)
# 17          1.976e-02  1.671e-03  square((((Tw - Ta) * sin(sin(theta) - -0.20433131)) * cos(eta ...
#                                   * -0.9885673)) / 14.176301)
# 18          1.628e-02  1.939e-01  square((((Tw - Ta) * sin(sin(theta) - -0.20433131)) * cos(sin(...
#                                   eta))) / (14.176301 + eta))
# 19          1.588e-02  2.456e-02  square((((Tw - Ta) * sin(sin(sin(theta)) - -0.140551)) * cos(s...
#                                   in(eta))) / (-12.539546 - eta))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.730e+05
# Head worker occupation: 6.8%
# Progress: 2381 / 15000 total iterations (15.873%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.150e+00  3.109e-07  0.6830067
# 2           1.026e+00  1.144e-01  sin(theta)
# 3           1.010e+00  1.571e-02  (Tw * 0.019040454)
# 4           9.466e-01  6.451e-02  cos2(Ta / Tw)
# 5           5.717e-01  5.043e-01  ((Tw - Ta) / 17.734062)
# 6           4.298e-01  2.852e-01  square((Tw - Ta) / 21.88175)
# 8           3.159e-01  1.539e-01  (((Tw - Ta) * sin(theta)) / 11.414657)
# 9           1.251e-01  9.264e-01  (square((Tw - Ta) / 17.496258) * sin(theta))
# 11          5.690e-02  3.939e-01  (square(((Tw - Ta) / 14.18742) - eta) * sin(theta))
# 12          1.918e-02  1.088e+00  ((square((Tw - Ta) / 15.158782) * cos2(eta)) * sin(theta))
# 13          1.918e-02  2.979e-07  ((square((Tw - Ta) / cube(-2.4748616)) * cos2(eta)) * sin(thet...
#                                   a))
# 15          1.917e-02  1.495e-04  ((square((Tw - Ta) / (-14.84788 - eta)) * sin(abs(theta))) * c...
#                                   os2(eta))
# 16          1.496e-02  2.479e-01  ((square((Tw - Ta) / 15.158782) * cos2(sin(sin(eta * -1.320057...
#                                   6)))) * sin(theta))
# 17          1.416e-02  5.492e-02  ((square((Tw - Ta) / -14.84788) * cos2(sin(abs(sin(eta * -1.32...
#                                   00576))))) * sin(theta))
# 19          1.322e-02  3.448e-02  ((square((Tw - Ta) / -16.18915) * ((square(cos2(sin(sin(eta)))...
#                                   ) - -0.20740855) - 0.027083142)) * sin(theta))
# 20          1.322e-02  5.066e-06  ((square((Tw - Ta) / -16.18915) * ((square(cos2(sin(sin(eta)))...
#                                   ) - -0.20740855) - sin(0.027083142))) * sin(theta))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.750e+05
# Head worker occupation: 7.3%
# Progress: 2973 / 15000 total iterations (19.820%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.150e+00  3.109e-07  0.6830067
# 2           1.026e+00  1.144e-01  sin(theta)
# 3           1.010e+00  1.571e-02  (Tw * 0.019040454)
# 4           9.466e-01  6.451e-02  cos2(Ta / Tw)
# 5           5.717e-01  5.043e-01  ((Tw - Ta) / 17.734062)
# 6           4.298e-01  2.852e-01  square((Tw - Ta) / 21.88175)
# 8           3.159e-01  1.539e-01  (((Tw - Ta) * sin(theta)) / 11.414657)
# 9           1.251e-01  9.264e-01  (square((Tw - Ta) / 17.496258) * sin(theta))
# 11          5.614e-02  4.007e-01  (square(((Tw - Ta) / 14.0563545) - eta) * sin(theta))
# 12          1.918e-02  1.074e+00  ((square((Tw - Ta) / -15.158716) * cos2(eta)) * sin(theta))
# 13          1.918e-02  1.787e-07  ((square((Tw - Ta) / cube(-2.4748616)) * cos2(eta)) * sin(thet...
#                                   a))
# 14          1.749e-02  9.202e-02  ((square((Tw - Ta) / -14.84788) * cos(eta - -0.24786782)) * si...
#                                   n(theta))
# 15          1.588e-02  9.646e-02  ((square((Tw - Ta) / -14.84788) * cos2(sin(eta * 1.1407543))) ...
#                                   * sin(theta))
# 16          1.331e-02  1.766e-01  ((square((Tw - Ta) / -14.84788) * cos2(sin(sin(eta) * -1.32005...
#                                   76))) * sin(theta))
# 17          1.289e-02  3.203e-02  ((square((Tw - Ta) / -14.84788) * square(cos2(sin(sin(sin(sin(...
#                                   eta))))))) * sin(theta))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.810e+05
# Head worker occupation: 7.9%
# Progress: 3630 / 15000 total iterations (24.200%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.150e+00  3.109e-07  0.6830067
# 2           1.026e+00  1.144e-01  sin(theta)
# 3           1.010e+00  1.571e-02  (Tw * 0.019040454)
# 4           9.466e-01  6.451e-02  cos2(Ta / Tw)
# 5           5.717e-01  5.043e-01  ((Tw - Ta) / 17.734062)
# 6           4.298e-01  2.852e-01  square((Tw - Ta) / 21.88175)
# 8           3.159e-01  1.539e-01  (((Tw - Ta) * sin(theta)) / 11.414657)
# 9           1.251e-01  9.264e-01  (square((Tw - Ta) / 17.496258) * sin(theta))
# 11          5.614e-02  4.007e-01  (square(((Tw - Ta) / 14.0563545) - eta) * sin(theta))
# 12          1.918e-02  1.074e+00  ((square((Tw - Ta) / -15.158716) * cos2(eta)) * sin(theta))
# 13          1.918e-02  1.787e-07  ((square((Tw - Ta) / cube(-2.4748616)) * cos2(eta)) * sin(thet...
#                                   a))
# 14          1.515e-02  2.358e-01  ((square((Tw - Ta) / 16.641684) * (1.3082474 - sin(eta))) * si...
#                                   n(theta))
# 15          1.468e-02  3.137e-02  ((square((Tw - Ta) / 16.641684) * (1.3082474 - sin(sin(eta))))...
#                                    * sin(theta))
# 16          1.313e-02  1.115e-01  ((square(((Tw - -0.5532081) - Ta) / 16.641684) * (1.3082474 - ...
#                                   sin(eta))) * sin(theta))
# 17          1.289e-02  1.849e-02  ((square((Tw - Ta) / -14.84788) * square(cos2(sin(sin(sin(sin(...
#                                   eta))))))) * sin(theta))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.980e+05
# Head worker occupation: 8.9%
# Progress: 4396 / 15000 total iterations (29.307%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.150e+00  3.109e-07  0.6830067
# 2           1.026e+00  1.144e-01  sin(theta)
# 3           1.010e+00  1.571e-02  (Tw * 0.019040454)
# 4           9.466e-01  6.451e-02  cos2(Ta / Tw)
# 5           5.717e-01  5.043e-01  ((Tw - Ta) / 17.734062)
# 6           4.298e-01  2.852e-01  square((Tw - Ta) / 21.88175)
# 8           3.159e-01  1.539e-01  (((Tw - Ta) * sin(theta)) / 11.414657)
# 9           1.251e-01  9.264e-01  (square((Tw - Ta) / 17.496258) * sin(theta))
# 11          5.614e-02  4.007e-01  (square(((Tw - Ta) / 14.0563545) - eta) * sin(theta))
# 12          1.918e-02  1.074e+00  ((square((Tw - Ta) / -15.158716) * cos2(eta)) * sin(theta))
# 13          1.599e-02  1.820e-01  ((square((Tw - Ta) / 16.641684) * (1.3614905 - eta)) * sin(the...
#                                   ta))
# 14          1.348e-02  1.703e-01  ((square((Tw - Ta) / 16.641684) * (1.3614905 - sin(eta))) * si...
#                                   n(theta))
# 16          1.285e-02  2.381e-02  (square(((Tw - Ta) / 14.81216) * cos2(sin(sin(sin(sin(eta)))))...
#                                   ) * sin(theta))
# 18          1.280e-02  2.067e-03  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta))))...
#                                    - -0.0058495426)) * sin(theta))
# 19          1.280e-02  4.171e-07  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta))))...
#                                    - sin(-0.0058495426))) * sin(theta))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.080e+05
# Head worker occupation: 8.5%
# Progress: 5084 / 15000 total iterations (33.893%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.150e+00  3.109e-07  0.6830067
# 2           1.026e+00  1.144e-01  sin(theta)
# 3           1.010e+00  1.571e-02  (Tw * 0.019040454)
# 4           9.466e-01  6.451e-02  cos2(Ta / Tw)
# 5           5.717e-01  5.043e-01  ((Tw - Ta) / 17.734062)
# 6           4.298e-01  2.852e-01  square((Tw - Ta) / 21.88182)
# 8           3.159e-01  1.539e-01  (((Tw - Ta) * sin(theta)) / 11.414657)
# 9           1.251e-01  9.264e-01  (square((Tw - Ta) / 17.496258) * sin(theta))
# 11          5.614e-02  4.007e-01  (square(((Tw - Ta) / 14.0563545) - eta) * sin(theta))
# 12          1.918e-02  1.074e+00  ((square((Tw - Ta) / -15.158716) * cos2(eta)) * sin(theta))
# 13          1.591e-02  1.866e-01  ((square((Tw - Ta) / -16.594032) * (1.3614905 - eta)) * sin(th...
#                                   eta))
# 14          1.330e-02  1.792e-01  ((square((Tw - Ta) / 16.641684) * (1.3284174 - sin(eta))) * si...
#                                   n(theta))
# 16          1.285e-02  1.710e-02  (square(((Tw - Ta) / 14.81216) * cos2(sin(sin(sin(sin(eta)))))...
#                                   ) * sin(theta))
# 18          1.280e-02  2.067e-03  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta))))...
#                                    - -0.0058495426)) * sin(theta))
# 19          1.280e-02  4.171e-07  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta))))...
#                                    - sin(-0.0058495426))) * sin(theta))
# 20          1.275e-02  3.933e-03  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta))) ...
#                                   - -0.0058495426) - -0.0058495426)) * sin(theta))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.200e+05
# Head worker occupation: 8.9%
# Progress: 5806 / 15000 total iterations (38.707%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.150e+00  3.109e-07  0.6830067
# 2           1.026e+00  1.144e-01  sin(theta)
# 3           1.010e+00  1.571e-02  (Tw * 0.019040454)
# 4           9.466e-01  6.451e-02  cos2(Ta / Tw)
# 5           5.717e-01  5.043e-01  ((Tw - Ta) / 17.734062)
# 6           4.298e-01  2.852e-01  square((Tw - Ta) / 21.88182)
# 8           3.159e-01  1.539e-01  (((Tw - Ta) * sin(theta)) / 11.414657)
# 9           1.251e-01  9.264e-01  (square((Tw - Ta) / 17.496258) * sin(theta))
# 11          5.614e-02  4.007e-01  (square(((Tw - Ta) / -14.056229) + eta) * sin(theta))
# 12          1.918e-02  1.074e+00  ((square((Tw - Ta) / -15.158716) * cos2(eta)) * sin(theta))
# 13          1.591e-02  1.866e-01  ((square((Tw - Ta) / -16.594032) * (1.3614905 - eta)) * sin(th...
#                                   eta))
# 14          1.330e-02  1.792e-01  ((square((Tw - Ta) / 16.641684) * (1.3284174 - sin(eta))) * si...
#                                   n(theta))
# 16          1.285e-02  1.710e-02  (square(((Tw - Ta) / 14.81216) * cos2(sin(sin(sin(sin(eta)))))...
#                                   ) * sin(theta))
# 18          1.280e-02  2.067e-03  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta))))...
#                                    - -0.0058495426)) * sin(theta))
# 19          1.280e-02  4.171e-07  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta))))...
#                                    - sin(-0.0058495426))) * sin(theta))
# 20          1.275e-02  4.211e-03  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta)) -...
#                                    -0.0058495426)) - -0.0058495426)) * sin(theta))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.300e+05
# Head worker occupation: 10.7%
# Progress: 6529 / 15000 total iterations (43.527%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.150e+00  3.109e-07  0.6830067
# 2           1.026e+00  1.144e-01  sin(theta)
# 3           1.010e+00  1.571e-02  (Tw * 0.019040454)
# 4           9.466e-01  6.451e-02  cos2(Ta / Tw)
# 5           5.717e-01  5.043e-01  ((Tw - Ta) / 17.734062)
# 6           4.298e-01  2.852e-01  square((Tw - Ta) / 21.88182)
# 8           3.159e-01  1.539e-01  (((Tw - Ta) * sin(theta)) / 11.414657)
# 9           1.251e-01  9.264e-01  (square((Tw - Ta) / 17.496258) * sin(theta))
# 11          5.614e-02  4.007e-01  (square(((Tw - Ta) / -14.056229) + eta) * sin(theta))
# 12          1.918e-02  1.074e+00  ((square((Tw - Ta) / -15.158716) * cos2(eta)) * sin(theta))
# 13          1.591e-02  1.866e-01  ((square((Tw - Ta) / -16.594032) * (1.3614905 - eta)) * sin(th...
#                                   eta))
# 14          1.301e-02  2.011e-01  ((square((Tw - Ta) / 16.582857) * (1.3284174 - sin(eta))) * si...
#                                   n(theta))
# 16          1.285e-02  6.168e-03  (square(((Tw - Ta) / 14.81216) * cos2(sin(sin(sin(sin(eta)))))...
#                                   ) * sin(theta))
# 18          1.280e-02  2.067e-03  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta))))...
#                                    - -0.0058495426)) * sin(theta))
# 19          1.280e-02  4.171e-07  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta))))...
#                                    - sin(-0.0058495426))) * sin(theta))
# 20          1.275e-02  4.211e-03  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta)) -...
#                                    -0.0058495426)) - -0.0058495426)) * sin(theta))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.260e+05
# Head worker occupation: 9.1%
# Progress: 7234 / 15000 total iterations (48.227%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.150e+00  3.109e-07  0.6830067
# 2           1.026e+00  1.144e-01  sin(theta)
# 3           1.010e+00  1.571e-02  (Tw * 0.019040454)
# 4           9.466e-01  6.451e-02  cos2(Ta / Tw)
# 5           5.717e-01  5.043e-01  ((Tw - Ta) / 17.734062)
# 6           4.298e-01  2.852e-01  square((Tw - Ta) / 21.88182)
# 8           3.159e-01  1.539e-01  (((Tw - Ta) * sin(theta)) / 11.414657)
# 9           1.251e-01  9.264e-01  (square((Tw - Ta) / 17.496258) * sin(theta))
# 11          5.614e-02  4.007e-01  (square(((Tw - Ta) / -14.056229) + eta) * sin(theta))
# 12          1.918e-02  1.074e+00  ((square((Tw - Ta) / -15.158716) * cos2(eta)) * sin(theta))
# 13          1.591e-02  1.866e-01  ((square((Tw - Ta) / -16.594032) * (1.3614905 - eta)) * sin(th...
#                                   eta))
# 14          1.298e-02  2.038e-01  ((square((Tw - Ta) / 16.582857) * (1.3445235 - sin(eta))) * si...
#                                   n(theta))
# 16          1.285e-02  4.781e-03  (square(((Tw - Ta) / 14.81216) * cos2(sin(sin(sin(sin(eta)))))...
#                                   ) * sin(theta))
# 18          1.276e-02  3.575e-03  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta) - ...
#                                   -0.01545519))))) * sin(theta))
# 20          1.275e-02  5.976e-04  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta)) -...
#                                    -0.0058495426)) - -0.0058495426)) * sin(theta))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.270e+05
# Head worker occupation: 9.3%
# Progress: 7952 / 15000 total iterations (53.013%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.150e+00  3.109e-07  0.6830067
# 2           1.026e+00  1.144e-01  sin(theta)
# 3           1.010e+00  1.571e-02  (Tw * 0.019040454)
# 4           9.466e-01  6.451e-02  cos2(Ta / Tw)
# 5           5.717e-01  5.043e-01  ((Tw - Ta) / 17.734062)
# 6           4.298e-01  2.852e-01  square((Tw - Ta) / 21.88182)
# 8           3.159e-01  1.539e-01  (((Tw - Ta) * sin(theta)) / 11.414657)
# 9           1.251e-01  9.264e-01  (square((Tw - Ta) / 17.496258) * sin(theta))
# 11          5.614e-02  4.007e-01  (square(((Tw - Ta) / -14.056229) + eta) * sin(theta))
# 12          1.918e-02  1.074e+00  ((square((Tw - Ta) / -15.158716) * cos2(eta)) * sin(theta))
# 13          1.591e-02  1.866e-01  ((square((Tw - Ta) / -16.594032) * (1.3614905 - eta)) * sin(th...
#                                   eta))
# 14          1.298e-02  2.038e-01  ((square((Tw - Ta) / 16.582857) * (1.3445235 - sin(eta))) * si...
#                                   n(theta))
# 16          1.285e-02  4.781e-03  (square(((Tw - Ta) / 14.81216) * cos2(sin(sin(sin(sin(eta)))))...
#                                   ) * sin(theta))
# 18          1.276e-02  3.575e-03  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta) - ...
#                                   -0.01545519))))) * sin(theta))
# 20          1.275e-02  6.285e-04  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta)) +...
#                                    0.0050409557)) - -0.0058495426)) * sin(theta))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.320e+05
# Head worker occupation: 10.5%
# Progress: 8708 / 15000 total iterations (58.053%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.150e+00  3.109e-07  0.6830067
# 2           1.026e+00  1.144e-01  sin(theta)
# 3           1.010e+00  1.571e-02  (Tw * 0.019040454)
# 4           9.466e-01  6.451e-02  cos2(Ta / Tw)
# 5           5.717e-01  5.043e-01  ((Tw - Ta) / 17.734062)
# 6           4.298e-01  2.852e-01  square((Tw - Ta) / 21.88182)
# 8           3.159e-01  1.539e-01  (((Tw - Ta) * sin(theta)) / 11.414657)
# 9           1.251e-01  9.264e-01  (square((Tw - Ta) / 17.496258) * sin(theta))
# 11          5.614e-02  4.007e-01  (square(((Tw - Ta) / -14.056229) + eta) * sin(theta))
# 12          1.918e-02  1.074e+00  ((square((Tw - Ta) / -15.158716) * cos2(eta)) * sin(theta))
# 13          1.591e-02  1.866e-01  ((square((Tw - Ta) / -16.594032) * (1.3614905 - eta)) * sin(th...
#                                   eta))
# 14          1.298e-02  2.038e-01  ((square((Tw - Ta) / 16.582857) * (1.3445235 - sin(eta))) * si...
#                                   n(theta))
# 16          1.285e-02  4.781e-03  (square(((Tw - Ta) / 14.81216) * cos2(sin(sin(sin(sin(eta)))))...
#                                   ) * sin(theta))
# 18          1.276e-02  3.575e-03  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta) - ...
#                                   -0.01545519))))) * sin(theta))
# 20          1.275e-02  6.285e-04  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta)) +...
#                                    0.0050409557)) - -0.0058495426)) * sin(theta))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.310e+05
# Head worker occupation: 9.1%
# Progress: 9415 / 15000 total iterations (62.767%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.150e+00  3.109e-07  0.6830067
# 2           1.026e+00  1.144e-01  sin(theta)
# 3           1.010e+00  1.571e-02  (Tw * 0.019040454)
# 4           9.466e-01  6.451e-02  cos2(Ta / Tw)
# 5           5.717e-01  5.043e-01  ((Tw - Ta) / 17.734062)
# 6           4.298e-01  2.852e-01  square((Tw - Ta) / 21.88182)
# 8           3.159e-01  1.539e-01  (((Tw - Ta) * sin(theta)) / 11.414657)
# 9           1.251e-01  9.264e-01  (square((Tw - Ta) / 17.496258) * sin(theta))
# 11          5.614e-02  4.007e-01  (square(((Tw - Ta) / -14.056229) + eta) * sin(theta))
# 12          1.918e-02  1.074e+00  ((square((Tw - Ta) / -15.158716) * cos2(eta)) * sin(theta))
# 13          1.586e-02  1.900e-01  ((square((Tw - Ta) / 16.582857) * (1.3628439 - eta)) * sin(the...
#                                   ta))
# 14          1.289e-02  2.070e-01  ((square((Tw - Ta) / -16.653717) * (1.3445235 - sin(eta))) * s...
#                                   in(theta))
# 16          1.285e-02  1.520e-03  (square(((Tw - Ta) / 14.81216) * cos2(sin(sin(sin(sin(eta)))))...
#                                   ) * sin(theta))
# 18          1.276e-02  3.575e-03  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta) - ...
#                                   -0.01545519))))) * sin(theta))
# 20          1.275e-02  6.285e-04  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta)) +...
#                                    0.0050409557)) - -0.0058495426)) * sin(theta))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.330e+05
# Head worker occupation: 8.9%
# Progress: 10148 / 15000 total iterations (67.653%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.150e+00  3.109e-07  0.6830067
# 2           1.026e+00  1.144e-01  sin(theta)
# 3           1.010e+00  1.571e-02  (Tw * 0.019040454)
# 4           9.466e-01  6.451e-02  cos2(Ta / Tw)
# 5           5.717e-01  5.043e-01  ((Tw - Ta) / 17.734062)
# 6           4.298e-01  2.852e-01  square((Tw - Ta) / 21.88182)
# 8           3.159e-01  1.539e-01  (((Tw - Ta) * sin(theta)) / 11.414657)
# 9           1.251e-01  9.264e-01  (square((Tw - Ta) / 17.496258) * sin(theta))
# 11          5.614e-02  4.007e-01  (square(((Tw - Ta) / -14.056229) + eta) * sin(theta))
# 12          1.918e-02  1.074e+00  ((square((Tw - Ta) / -15.158716) * cos2(eta)) * sin(theta))
# 13          1.543e-02  2.171e-01  ((square((Tw - Ta) / -16.653717) * (1.3858562 - eta)) * sin(th...
#                                   eta))
# 14          1.289e-02  1.799e-01  ((square((Tw - Ta) / -16.653717) * (1.3445235 - sin(eta))) * s...
#                                   in(theta))
# 16          1.285e-02  1.520e-03  (square(((Tw - Ta) / 14.81216) * cos2(sin(sin(sin(sin(eta)))))...
#                                   ) * sin(theta))
# 18          1.276e-02  3.575e-03  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta) - ...
#                                   -0.01545519))))) * sin(theta))
# 20          1.275e-02  6.285e-04  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta)) +...
#                                    0.0050409557)) - -0.0058495426)) * sin(theta))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.340e+05
# Head worker occupation: 9.3%
# Progress: 10864 / 15000 total iterations (72.427%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.150e+00  3.109e-07  0.6830067
# 2           1.026e+00  1.144e-01  sin(theta)
# 3           1.010e+00  1.571e-02  (Tw * 0.019040454)
# 4           9.466e-01  6.451e-02  cos2(Ta / Tw)
# 5           5.717e-01  5.043e-01  ((Tw - Ta) / 17.734062)
# 6           4.298e-01  2.852e-01  square((Tw - Ta) / 21.88182)
# 8           3.159e-01  1.539e-01  (((Tw - Ta) * sin(theta)) / 11.414657)
# 9           1.251e-01  9.264e-01  (square((Tw - Ta) / 17.496258) * sin(theta))
# 11          5.614e-02  4.007e-01  (square(((Tw - Ta) / -14.056229) + eta) * sin(theta))
# 12          1.918e-02  1.074e+00  ((square((Tw - Ta) / -15.158716) * cos2(eta)) * sin(theta))
# 13          1.543e-02  2.171e-01  ((square((Tw - Ta) / -16.653717) * (1.3858562 - eta)) * sin(th...
#                                   eta))
# 14          1.289e-02  1.799e-01  ((square((Tw - Ta) / -16.653717) * (1.3445235 - sin(eta))) * s...
#                                   in(theta))
# 16          1.285e-02  1.520e-03  (square(((Tw - Ta) / 14.81216) * cos2(sin(sin(sin(sin(eta)))))...
#                                   ) * sin(theta))
# 18          1.276e-02  3.575e-03  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta) - ...
#                                   -0.01545519))))) * sin(theta))
# 20          1.269e-02  3.036e-03  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta) - ...
#                                   (-0.01545519 / theta)))))) * sin(theta))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.310e+05
# Head worker occupation: 7.8%
# Progress: 11593 / 15000 total iterations (77.287%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.150e+00  3.109e-07  0.6830067
# 2           1.026e+00  1.144e-01  sin(theta)
# 3           1.010e+00  1.571e-02  (Tw * 0.019040454)
# 4           9.466e-01  6.451e-02  cos2(Ta / Tw)
# 5           5.717e-01  5.043e-01  ((Tw - Ta) / 17.734062)
# 6           4.298e-01  2.852e-01  square((Tw - Ta) / 21.88182)
# 8           3.159e-01  1.539e-01  (((Tw - Ta) * sin(theta)) / 11.414657)
# 9           1.251e-01  9.264e-01  (square((Tw - Ta) / 17.496258) * sin(theta))
# 11          5.614e-02  4.007e-01  (square(((Tw - Ta) / -14.056229) + eta) * sin(theta))
# 12          1.918e-02  1.074e+00  ((square((Tw - Ta) / -15.158716) * cos2(eta)) * sin(theta))
# 13          1.543e-02  2.171e-01  ((square((Tw - Ta) / -16.653717) * (1.3858562 - eta)) * sin(th...
#                                   eta))
# 14          1.289e-02  1.799e-01  ((square((Tw - Ta) / -16.653717) * (1.3445235 - sin(eta))) * s...
#                                   in(theta))
# 16          1.285e-02  1.520e-03  (square(((Tw - Ta) / 14.81216) * cos2(sin(sin(sin(sin(eta)))))...
#                                   ) * sin(theta))
# 18          1.275e-02  3.935e-03  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta)) -...
#                                    -0.013967374)))) * sin(theta))
# 19          1.275e-02  1.073e-06  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta)) -...
#                                    sin(-0.013967374))))) * sin(theta))
# 20          1.268e-02  5.905e-03  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta)) -...
#                                    (-0.013967374 / theta))))) * sin(theta))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.310e+05
# Head worker occupation: 6.4%
# Progress: 12315 / 15000 total iterations (82.100%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.150e+00  3.109e-07  0.6830067
# 2           1.026e+00  1.144e-01  sin(theta)
# 3           1.010e+00  1.571e-02  (Tw * 0.019040454)
# 4           9.466e-01  6.451e-02  cos2(Ta / Tw)
# 5           5.717e-01  5.043e-01  ((Tw - Ta) / 17.734062)
# 6           4.298e-01  2.852e-01  square((Tw - Ta) / 21.88182)
# 8           3.159e-01  1.539e-01  (((Tw - Ta) * sin(theta)) / 11.414657)
# 9           1.251e-01  9.264e-01  (square((Tw - Ta) / 17.496258) * sin(theta))
# 11          5.614e-02  4.007e-01  (square(((Tw - Ta) / -14.056229) + eta) * sin(theta))
# 12          1.918e-02  1.074e+00  ((square((Tw - Ta) / -15.158716) * cos2(eta)) * sin(theta))
# 13          1.538e-02  2.207e-01  ((square((Tw - Ta) / -16.653717) * (1.3804318 - eta)) * sin(th...
#                                   eta))
# 14          1.289e-02  1.762e-01  ((square((Tw - Ta) / -16.653717) * (1.3445235 - sin(eta))) * s...
#                                   in(theta))
# 16          1.285e-02  1.520e-03  (square(((Tw - Ta) / 14.81216) * cos2(sin(sin(sin(sin(eta)))))...
#                                   ) * sin(theta))
# 18          1.275e-02  3.935e-03  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta)) -...
#                                    -0.013967374)))) * sin(theta))
# 19          1.275e-02  1.073e-06  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta)) -...
#                                    sin(-0.013967374))))) * sin(theta))
# 20          1.268e-02  5.905e-03  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta)) -...
#                                    (-0.013967374 / theta))))) * sin(theta))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.300e+05
# Head worker occupation: 7.9%
# Progress: 13037 / 15000 total iterations (86.913%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.150e+00  3.109e-07  0.6830067
# 2           1.026e+00  1.144e-01  sin(theta)
# 3           1.010e+00  1.571e-02  (Tw * 0.019040454)
# 4           9.466e-01  6.451e-02  cos2(Ta / Tw)
# 5           5.717e-01  5.043e-01  ((Tw - Ta) / 17.734062)
# 6           4.298e-01  2.852e-01  square((Tw - Ta) / 21.88182)
# 8           3.159e-01  1.539e-01  (((Tw - Ta) * sin(theta)) / 11.414657)
# 9           1.251e-01  9.264e-01  (square((Tw - Ta) / 17.496258) * sin(theta))
# 11          5.614e-02  4.007e-01  (square(((Tw - Ta) / -14.056229) + eta) * sin(theta))
# 12          1.918e-02  1.074e+00  ((square((Tw - Ta) / -15.158716) * cos2(eta)) * sin(theta))
# 13          1.538e-02  2.207e-01  ((square((Tw - Ta) / -16.653717) * (1.3804318 - eta)) * sin(th...
#                                   eta))
# 14          1.289e-02  1.762e-01  ((square((Tw - Ta) / -16.653717) * (1.3445235 - sin(eta))) * s...
#                                   in(theta))
# 16          1.285e-02  1.520e-03  (square(((Tw - Ta) / 14.81216) * cos2(sin(sin(sin(sin(eta)))))...
#                                   ) * sin(theta))
# 18          1.275e-02  3.935e-03  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta)) -...
#                                    -0.013967374)))) * sin(theta))
# 19          1.275e-02  1.073e-06  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta)) -...
#                                    sin(-0.013967374))))) * sin(theta))
# 20          1.268e-02  5.905e-03  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta)) -...
#                                    (-0.013967374 / theta))))) * sin(theta))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.320e+05
# Head worker occupation: 9.6%
# Progress: 13772 / 15000 total iterations (91.813%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.150e+00  3.109e-07  0.6830067
# 2           1.026e+00  1.144e-01  sin(theta)
# 3           1.010e+00  1.571e-02  (Tw * 0.019040454)
# 4           9.466e-01  6.451e-02  cos2(Ta / Tw)
# 5           5.717e-01  5.043e-01  ((Tw - Ta) / 17.734062)
# 6           4.298e-01  2.852e-01  square((Tw - Ta) / 21.88182)
# 8           3.159e-01  1.539e-01  (((Tw - Ta) * sin(theta)) / 11.414657)
# 9           1.251e-01  9.264e-01  (square((Tw - Ta) / 17.496258) * sin(theta))
# 11          5.614e-02  4.007e-01  (square(((Tw - Ta) / -14.056229) + eta) * sin(theta))
# 12          1.918e-02  1.074e+00  ((square((Tw - Ta) / -15.158716) * cos2(eta)) * sin(theta))
# 13          1.538e-02  2.207e-01  ((square((Tw - Ta) / -16.653717) * (1.3804318 - eta)) * sin(th...
#                                   eta))
# 14          1.289e-02  1.762e-01  ((square((Tw - Ta) / -16.653717) * (1.3445235 - sin(eta))) * s...
#                                   in(theta))
# 16          1.285e-02  1.520e-03  (square(((Tw - Ta) / 14.81216) * cos2(sin(sin(sin(sin(eta)))))...
#                                   ) * sin(theta))
# 18          1.275e-02  3.935e-03  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta)) -...
#                                    -0.013967374)))) * sin(theta))
# 19          1.275e-02  1.073e-06  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta)) -...
#                                    sin(-0.013967374))))) * sin(theta))
# 20          1.268e-02  5.905e-03  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta)) -...
#                                    (-0.013967374 / theta))))) * sin(theta))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.320e+05
# Head worker occupation: 8.7%
# Progress: 14486 / 15000 total iterations (96.573%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.150e+00  3.109e-07  0.6830067
# 2           1.026e+00  1.144e-01  sin(theta)
# 3           1.010e+00  1.571e-02  (Tw * 0.019040454)
# 4           9.466e-01  6.451e-02  cos2(Ta / Tw)
# 5           5.717e-01  5.043e-01  ((Tw - Ta) / 17.734062)
# 6           4.298e-01  2.852e-01  square((Tw - Ta) / 21.88182)
# 8           3.159e-01  1.539e-01  (((Tw - Ta) * sin(theta)) / 11.414657)
# 9           1.251e-01  9.264e-01  (square((Tw - Ta) / 17.496258) * sin(theta))
# 11          5.614e-02  4.007e-01  (square(((Tw - Ta) / -14.056229) + eta) * sin(theta))
# 12          1.918e-02  1.074e+00  ((square((Tw - Ta) / -15.158716) * cos2(eta)) * sin(theta))
# 13          1.530e-02  2.257e-01  ((square((Tw - Ta) / 16.812712) * (1.3804318 - eta)) * sin(the...
#                                   ta))
# 14          1.289e-02  1.714e-01  ((square((Tw - Ta) / 16.647968) * (1.3445235 - sin(eta))) * si...
#                                   n(theta))
# 16          1.285e-02  1.446e-03  (square(((Tw - Ta) / 14.81216) * cos2(sin(sin(sin(sin(eta)))))...
#                                   ) * sin(theta))
# 18          1.275e-02  3.935e-03  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta)) -...
#                                    -0.013967374)))) * sin(theta))
# 19          1.275e-02  1.073e-06  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta)) -...
#                                    sin(-0.013967374))))) * sin(theta))
# 20          1.268e-02  5.905e-03  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin(sin(sin(eta)) -...
#                                    (-0.013967374 / theta))))) * sin(theta))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                          0.6830067
# 	1         0.114405                                         sin(theta)
# 	2         0.015705                                 (Tw * 0.019040454)
# 	3         0.064508                                      cos2(Ta / Tw)
# 	4         0.504256                            ((Tw - Ta) / 17.734062)
# 	5         0.285202                       square((Tw - Ta) / 21.88182)
# 	6         0.153915             (((Tw - Ta) * sin(theta)) / 11.414657)
# 	7         0.926354       (square((Tw - Ta) / 17.496258) * sin(theta))
# 	8         0.400656  (square(((Tw - Ta) / -14.056229) + eta) * sin(...
# 	9         1.074180  ((square((Tw - Ta) / -15.158716) * cos2(eta)) ...
# 	10  >>>>  0.225735  ((square((Tw - Ta) / 16.812712) * (1.3804318 -...
# 	11        0.171356  ((square((Tw - Ta) / 16.647968) * (1.3445235 -...
# 	12        0.001446  (square(((Tw - Ta) / 14.81216) * cos2(sin(sin(...
# 	13        0.003935  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin...
# 	14        0.000001  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin...
# 	15        0.005905  (square(((Tw - Ta) / 14.724996) * cos2(sin(sin...
#
# 	        loss  complexity
# 	0   1.149930           1
# 	1   1.025619           2
# 	2   1.009637           3
# 	3   0.946564           4
# 	4   0.571682           5
# 	5   0.429826           6
# 	6   0.315940           8
# 	7   0.125110           9
# 	8   0.056142          11
# 	9   0.019177          12
# 	10  0.015302          13
# 	11  0.012892          14
# 	12  0.012855          16
# 	13  0.012754          18
# 	14  0.012754          19
# 	15  0.012679          20
# ]

# %%
from sklearn.metrics import mean_squared_error

#print(model)
#print(model.predict(X, 11))

for k in range(17):
    pred = model.predict(X, k)
    err = mean_squared_error(Y, pred)
    print(k, err)
# Out:
# 0 1.1499304045516108
# 1 1.0256187590418555
# 2 1.0096372068679893
# 3 0.9442137703362646
# 4 0.5716818689835105
# 5 0.429826258396103
# 6 0.315939704512936
# 7 0.1251105061590083
# 8 0.056142070846614725
# 9 0.019176886828392945
# 10 0.016050304642276473
# 11 0.012722027249519175
# 12 0.012720963597696837
# 13 0.012716963162983834
# 14 0.012660242267847838
# 15 0.011126912235004902
# 16 0.01098580436394301
